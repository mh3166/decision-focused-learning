# %% [markdown]
# # Imports

# %%
import importlib
from functools import partial

from torch import nn
import torch
from torch.utils.data import DataLoader
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import pandas as pd
import copy

from decision_learning.benchmarks.shortest_path_grid.data import genData
from decision_learning.modeling.loss import SPOPlus, get_loss_function
from decision_learning.modeling.models import LinearRegression
from decision_learning.modeling.val_metrics import decision_regret
from decision_learning.modeling.train import train, calc_test_regret, init_loss_data_pretraining, filter_kwargs

# %% [markdown]
# ### Example Solver/Optimization Model
# - Below, `shortest_path_solver` is a custom user optimization model specified in the form of a callable function, and its first input argument is the vector of costs. The rest of the input arguments size, sens, need to be pre-set before being passed to `pipeline`, `train`, or any loss function. This can be accomplished using the `partial` python function (see example below). The exact implementation is not important but mainly that it:
#     - accepts a costs vector input
#     - returns solution (sol) and objective value (obj) for the input cost vector
# - Note that `shortest_path_solver` also has two returns: sol, obj

# %%
def shortest_path_solver(costs, size, sens = 1e-4):
    # Forward Pass
    starting_ind = 0
    starting_ind_c = 0
    samples = costs.shape[0]
    V_arr = torch.zeros(samples, size ** 2)
    for i in range(0, 2 * (size - 1)):
        num_nodes = min(i + 1, 9 - i)
        num_nodes_next = min(i + 2, 9 - i - 1)
        num_arcs = 2 * (max(num_nodes, num_nodes_next) - 1)
        V_1 = V_arr[:, starting_ind:starting_ind + num_nodes]
        layer_costs = costs[:, starting_ind_c:starting_ind_c + num_arcs]
        l_costs = layer_costs[:, 0::2]
        r_costs = layer_costs[:, 1::2]
        next_V_val_l = torch.ones(samples, num_nodes_next) * float('inf')
        next_V_val_r = torch.ones(samples, num_nodes_next) * float('inf')
        if num_nodes_next > num_nodes:
            next_V_val_l[:, :num_nodes_next - 1] = V_1 + l_costs
            next_V_val_r[:, 1:num_nodes_next] = V_1 + r_costs
        else:
            next_V_val_l = V_1[:, :num_nodes_next] + l_costs
            next_V_val_r = V_1[:, 1:num_nodes_next + 1] + r_costs
        next_V_val = torch.minimum(next_V_val_l, next_V_val_r)
        V_arr[:, starting_ind + num_nodes:starting_ind + num_nodes + num_nodes_next] = next_V_val

        starting_ind += num_nodes
        starting_ind_c += num_arcs

    # Backward Pass
    starting_ind = size ** 2
    starting_ind_c = costs.shape[1]
    prev_act = torch.ones(samples, 1)
    sol = torch.zeros(costs.shape)
    for i in range(2 * (size - 1), 0, -1):
        num_nodes = min(i + 1, 9 - i)
        num_nodes_next = min(i, 9 - i + 1)
        V_1 = V_arr[:, starting_ind - num_nodes:starting_ind]
        V_2 = V_arr[:, starting_ind - num_nodes - num_nodes_next:starting_ind - num_nodes]

        num_arcs = 2 * (max(num_nodes, num_nodes_next) - 1)
        layer_costs = costs[:, starting_ind_c - num_arcs: starting_ind_c]

        if num_nodes < num_nodes_next:
            l_cs_res = ((V_2[:, :num_nodes_next - 1] - V_1 + layer_costs[:, ::2]) < sens) * prev_act
            r_cs_res = ((V_2[:, 1:num_nodes_next] - V_1 + layer_costs[:, 1::2]) < sens) * prev_act
            prev_act = torch.zeros(V_2.shape)
            prev_act[:, :num_nodes_next - 1] += l_cs_res
            prev_act[:, 1:num_nodes_next] += r_cs_res
        else:
            l_cs_res = ((V_2 - V_1[:, :num_nodes - 1] + layer_costs[:, ::2]) < sens) * prev_act[:, :num_nodes - 1]
            r_cs_res = ((V_2 - V_1[:, 1:num_nodes] + layer_costs[:, 1::2]) < sens) * prev_act[:, 1:num_nodes]
            prev_act = torch.zeros(V_2.shape)
            prev_act += l_cs_res
            prev_act += r_cs_res
        cs = torch.zeros(layer_costs.shape)
        cs[:, ::2] = l_cs_res
        cs[:, 1::2] = r_cs_res
        sol[:, starting_ind_c - num_arcs: starting_ind_c] = cs

        starting_ind = starting_ind - num_nodes
        starting_ind_c = starting_ind_c - num_arcs
    # Dimension (samples, num edges)
    obj = torch.sum(sol * costs, axis=1)
    # Dimension (samples, 1)
    return sol.to(torch.float32), obj.reshape(-1,1).to(torch.float32)

# %% [markdown]
# ### Create Experiments Grid
# This shortest path experiment has two important settings:
# - number of samples: less samples means higher error/more noise, more samples means lower error/less noise
# - epsilon: noise level on edge costs, can be uniformly distributed multiplicative noise, or normally distributed additive noise
# - This example below creates 100 trials for 8 different settings

# %%
# control the randomization seeding for pytorch
torch.manual_seed(105)
indices_arr = torch.randperm(100000)
indices_arr_test = torch.randperm(100000)

n_arr = [200, 400, 800, 1600] # array of number of samples for an experiment
ep_arr = ['unif', 'normal'] # noise type
trials = 100 # number of trials per setting

# create an array where each item is [number of samples, noise type, trial number] representing an experiment run
exp_arr = []
for n in n_arr:
    for ep in ep_arr:
        for t in range(trials):
            exp_arr.append([n, ep, t]) # add current [number of samples, noise type, trial number] experiment run setting

# %%
# setup
sim = 0 # simulation trial number, only show one experiment run for demonstration purposes
exp = exp_arr[sim] # current experiment
num_data = exp[0]  # number of training data
ep_type = exp[1] # noise type of current experiment
trial = exp[2] # trial number of current experiment

# shortest path problem data generation parameters - https://arxiv.org/pdf/2402.03256
grid = (5, 5)  # grid size
num_feat = 5  # size of feature
deg = 6  # polynomial degree in edge cost function
e = .3  # noise width/amount of noise

# path planting for shortest path example - see page 9, subsection "Harder Example with Planted Arcs" in section 4.2 of paper https://arxiv.org/pdf/2402.03256
planted_good_pwl_params = {'slope0':0, # slope of first segment of piecewise linear cost function for "good" edge cost planted
                    'int0':2, # intercept of first segment of piecewise linear cost function for "good" edge cost planted
                    'slope1':0, # slope of second segment of piecewise linear cost function for "good" edge cost planted
                    'int1':2} # intercept of second segment of piecewise linear cost function for "good" edge cost planted
planted_bad_pwl_params = {'slope0':4, # slope of first segment of piecewise linear cost function for "bad" edge cost planted
                    'int0':0, # intercept of first segment of piecewise linear cost function for "bad" edge cost planted
                    'slope1':0, # slope of second segment of piecewise linear cost function for "bad" edge cost planted
                    'int1':2.2} # intercept of second segment of piecewise linear cost function for "bad" edge cost planted
plant_edge = True # to plant edges in shortest path experiment or not

print(f'current experiment setting: number of data points {num_data}, epsilon type {ep_type}, trial number {trial}')
# Out:
# current experiment setting: number of data points 200, epsilon type unif, trial number 0

# %% [markdown]
# ### Calling `genData` from `decision_learning.benchmarks.shortest_path_grid.data`

# %%
# ------------DATA------------
# training data
generated_data = genData(num_data=num_data+200, # number of data points to generate for training set
        num_features=num_feat, # number of features 
        grid=grid, # grid shape
        deg=deg, # polynomial degree
        noise_type=ep_type, # epsilon noise type
        noise_width=e, # amount of noise
        seed=indices_arr[trial], # seed the randomness
        plant_edges=plant_edge, # to plant edges or not
        planted_good_pwl_params=planted_good_pwl_params, # cost function for good edges
        planted_bad_pwl_params=planted_bad_pwl_params) # cost function for bad edges

# testing data
generated_data_test = genData(num_data=10000, # number of data points to generate for test set
        num_features=num_feat, # number of features 
        grid=grid,  # grid shape
        deg=deg,  # polynomial degree
        noise_type=ep_type,  # epsilon noise type
        noise_width=e, # amount of noise
        seed=indices_arr_test[trial],      # seed the randomness
        plant_edges=plant_edge, # to plant edges or not
        planted_good_pwl_params=planted_good_pwl_params, # cost function for good edges
        planted_bad_pwl_params=planted_bad_pwl_params) # cost function for bad edges

# %% [markdown]
# ### Split Data into train, val and create structured data inputs
# For many decision aware loss function experiment processes, we need the following four:
# - X: features
# - true_cost: true cost associated with each X
# - true_sol: true solution of LP given true_cost
# - true_obj: true objective of LP given true_cost
#
# In this case, we will need to get the `true_sol` and `true_obj` for each data sample/`true_cost` vector by plugging into our optimization solver. The code block below shows this.
#
# Furthermore, this package's training loop, in order to flexibly handle different loss function signatures and behavior, requires data to be organized as dictionaries mapping key->data where the keys correspond to named arguments in the loss function. This way, the training loop can flexibly inject or remove the correct named arguments to each loss function

# %%
# training data - get true_sol, true_obj
sol, obj = shortest_path_solver(costs=generated_data['cost'], size=5) # plug into solver
# get structured data in the form of dictionary
final_data = {'X':generated_data['feat'],
              'true_cost':generated_data['cost'],
              'true_sol':sol,
              'true_obj':obj}

# ------------------TRAIN/VAL SPLIT--------------------
train_dict = {}
val_dict = {}

# For each (key,value) tuple in final_data, we split into train val split
# using sklearn train_test_split. Because the test_size, random_state seed are
# always the same, ensures each (key,value) are split the same way across indices
# (this behavior has been checked/tested)
for key, value in final_data.items():
    train_data, val_data = train_test_split(value, test_size=200, random_state=42)
    train_dict[key] = train_data
    val_dict[key] = val_data
    
# test data - get true_sol, true_obj and structured data form
sol_test, obj_test = shortest_path_solver(costs=generated_data_test['cost_true'], size=5)
final_data_test = {'X':generated_data_test['feat'],
              'true_cost':generated_data_test['cost_true'],
              'true_sol':sol_test,
              'true_obj':obj_test}
# Out:
# /var/folders/k9/q1b_kr4s353_ckw475n0fxw40000gn/T/ipykernel_55518/1886646261.py:18: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   next_V_val_l[:, :num_nodes_next - 1] = V_1 + l_costs
# /var/folders/k9/q1b_kr4s353_ckw475n0fxw40000gn/T/ipykernel_55518/1886646261.py:19: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   next_V_val_r[:, 1:num_nodes_next] = V_1 + r_costs
# /var/folders/k9/q1b_kr4s353_ckw475n0fxw40000gn/T/ipykernel_55518/1886646261.py:21: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   next_V_val_l = V_1[:, :num_nodes_next] + l_costs
# /var/folders/k9/q1b_kr4s353_ckw475n0fxw40000gn/T/ipykernel_55518/1886646261.py:22: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   next_V_val_r = V_1[:, 1:num_nodes_next + 1] + r_costs
# /var/folders/k9/q1b_kr4s353_ckw475n0fxw40000gn/T/ipykernel_55518/1886646261.py:44: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   l_cs_res = ((V_2[:, :num_nodes_next - 1] - V_1 + layer_costs[:, ::2]) < sens) * prev_act
# /var/folders/k9/q1b_kr4s353_ckw475n0fxw40000gn/T/ipykernel_55518/1886646261.py:45: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   r_cs_res = ((V_2[:, 1:num_nodes_next] - V_1 + layer_costs[:, 1::2]) < sens) * prev_act
# /var/folders/k9/q1b_kr4s353_ckw475n0fxw40000gn/T/ipykernel_55518/1886646261.py:50: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   l_cs_res = ((V_2 - V_1[:, :num_nodes - 1] + layer_costs[:, ::2]) < sens) * prev_act[:, :num_nodes - 1]
# /var/folders/k9/q1b_kr4s353_ckw475n0fxw40000gn/T/ipykernel_55518/1886646261.py:51: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   r_cs_res = ((V_2 - V_1[:, 1:num_nodes] + layer_costs[:, 1::2]) < sens) * prev_act[:, 1:num_nodes]
# /var/folders/k9/q1b_kr4s353_ckw475n0fxw40000gn/T/ipykernel_55518/1886646261.py:63: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   obj = torch.sum(sol * costs, axis=1)

# %% [markdown]
# ## Prediction Model
# - Any decision-aware/focused problem will of course need prediction model to predict the cost/coefficient vector given contextual input/features. This example uses a simple `LinearRegression` object implemented within `decision_learning.modeling.models`.
# - The package expects the prediction model to be a PyTorch model since PyTorch offers convenient autograd functionality/allows user to specify custom losses/backwards passes that are found within many decision-aware/focused works.

# %%
# ------------prediction model------------
pred_model = LinearRegression(input_dim=generated_data['feat'].shape[1],
                 output_dim=generated_data['cost'].shape[1])

# %% [markdown]
# ## CosineSurrogate

# %%
import importlib

from decision_learning.modeling.train import init_loss_data_pretraining

import decision_learning.modeling.loss
importlib.reload(decision_learning.modeling.loss)
from decision_learning.modeling.loss import get_loss_function, CosineSurrogateDotProdMSE, CosineSurrogateDotProdVecMag

# %%
# Prediction Model
pred_model = LinearRegression(input_dim=train_dict['X'].shape[1],
                 output_dim=train_dict['true_cost'].shape[1])

# optimization solver
optmodel = partial(shortest_path_solver,size=5)

# loss function
loss_fn = CosineSurrogateDotProdVecMag(alpha=1)

# training, validation data
train_data_dict = train_dict
train_data_dict.update({'input2':train_dict['true_cost'], 
                       'target':torch.ones(train_dict['true_cost'].shape[0])}) # extra input key needed for loss function

val_data_dict = val_dict

# %%
train_dataset, train_loader = init_loss_data_pretraining(train_data_dict, 
                        dataloader_params={'batch_size':32, 'shuffle':True})  # training data

# %%
true_cost = train_dataset.data['true_cost']
pred = pred_model(train_dataset.data['X'])

# %%
loss_fn.reduction = 'none'
loss = loss_fn(pred_cost=pred, true_cost=true_cost)

# %%
loss_fn.alpha*torch.sum(pred[0]*pred[0]), torch.sum(pred[0]*true_cost[0]), loss_fn.alpha*torch.sum(pred[0]*pred[0]) - torch.sum(pred[0]*true_cost[0])
# Out:
# (tensor(10.6915, grad_fn=<MulBackward0>),
#  tensor(1.4228, grad_fn=<SumBackward0>),
#  tensor(9.2686, grad_fn=<SubBackward0>))

# %% [markdown]
# # Train Function

# %%
import importlib

import decision_learning.modeling.loss
importlib.reload(decision_learning.modeling.loss)
from decision_learning.modeling.loss import get_loss_function, CosineSurrogateDotProdMSE, CosineSurrogateDotProdVecMag

# %%
# Prediction Model
pred_model = LinearRegression(input_dim=train_dict['X'].shape[1],
                 output_dim=train_dict['true_cost'].shape[1])

# optimization solver
optmodel = partial(shortest_path_solver,size=5)

# loss function
loss_fn = CosineSurrogateDotProdVecMag(alpha=5)

# training, validation data
train_data_dict = train_dict
train_data_dict.update({'input2':train_dict['true_cost'], 
                       'target':torch.ones(train_dict['true_cost'].shape[0])}) # extra input key needed for loss function

val_data_dict = val_dict

# %%
metrics, trained_model = train(pred_model=pred_model,
                optmodel=optmodel,
                loss_fn=loss_fn,
                train_data_dict=train_data_dict,
                val_data_dict=val_data_dict,
                test_data_dict=final_data_test, # test data dictionary
                num_epochs=100,
                lr=0.1,
                scheduler_params={'step_size': 10, 'gamma': 0.1},
                minimization=False)
# Out:
# 2025-01-22 09:49:27,043 - decision_learning.modeling.train - INFO - Training on device: cpu
# Training Loader: Epoch 1/100: 100%|██████████| 7/7 [00:00<00:00, 1090.64it/s]
# Validation Loader: Epoch 1/100: 100%|██████████| 7/7 [00:00<00:00, 2639.59it/s]
# 2025-01-22 09:49:27,067 - decision_learning.modeling.train - INFO - epoch: 1, train_loss: 17.036829803671157, val_metric: -0.33815249707005035, test_regret: 0.22699389178912618
# Training Loader: Epoch 2/100: 100%|██████████| 7/7 [00:00<00:00, 1295.51it/s]
# Validation Loader: Epoch 2/100: 100%|██████████| 7/7 [00:00<00:00, 3450.07it/s]
# 2025-01-22 09:49:27,085 - decision_learning.modeling.train - INFO - epoch: 2, train_loss: -2.4025398322514127, val_metric: -0.3552398346399721, test_regret: 0.18270424998434606
# Training Loader: Epoch 3/100: 100%|██████████| 7/7 [00:00<00:00, 1462.30it/s]
# Validation Loader: Epoch 3/100: 100%|██████████| 7/7 [00:00<00:00, 3217.90it/s]
# 2025-01-22 09:49:27,102 - decision_learning.modeling.train - INFO - epoch: 3, train_loss: -9.259743009294782, val_metric: -0.20400756472815706, test_regret: 0.11131173635513412
# Training Loader: Epoch 4/100: 100%|██████████| 7/7 [00:00<00:00, 1831.46it/s]
# Validation Loader: Epoch 4/100: 100%|██████████| 7/7 [00:00<00:00, 3038.41it/s]
# 2025-01-22 09:49:27,120 - decision_learning.modeling.train - INFO - epoch: 4, train_loss: -11.247399057660784, val_metric: -0.2613077042203293, test_regret: 0.15241783061967196
# Training Loader: Epoch 5/100: 100%|██████████| 7/7 [00:00<00:00, 1817.29it/s]
# Validation Loader: Epoch 5/100: 100%|██████████| 7/7 [00:00<00:00, 3298.89it/s]
# 2025-01-22 09:49:27,135 - decision_learning.modeling.train - INFO - epoch: 5, train_loss: -13.196652957371303, val_metric: -0.300556167910948, test_regret: 0.09989647969647132
# Training Loader: Epoch 6/100: 100%|██████████| 7/7 [00:00<00:00, 1677.43it/s]
# Validation Loader: Epoch 6/100: 100%|██████████| 7/7 [00:00<00:00, 2820.38it/s]
# 2025-01-22 09:49:27,152 - decision_learning.modeling.train - INFO - epoch: 6, train_loss: -14.959138461521693, val_metric: -0.20791282988171533, test_regret: 0.06778526554692088
# Training Loader: Epoch 7/100: 100%|██████████| 7/7 [00:00<00:00, 1504.72it/s]
# Validation Loader: Epoch 7/100: 100%|██████████| 7/7 [00:00<00:00, 2877.03it/s]
# 2025-01-22 09:49:27,169 - decision_learning.modeling.train - INFO - epoch: 7, train_loss: -15.209792818341937, val_metric: -0.23136302749317403, test_regret: 0.08141893884213988
# Training Loader: Epoch 8/100: 100%|██████████| 7/7 [00:00<00:00, 1530.05it/s]
# Validation Loader: Epoch 8/100: 100%|██████████| 7/7 [00:00<00:00, 3081.13it/s]
# 2025-01-22 09:49:27,186 - decision_learning.modeling.train - INFO - epoch: 8, train_loss: -15.282945360456194, val_metric: -0.21960525068794048, test_regret: 0.058885066766986356
# Training Loader: Epoch 9/100: 100%|██████████| 7/7 [00:00<00:00, 1548.94it/s]
# Validation Loader: Epoch 9/100: 100%|██████████| 7/7 [00:00<00:00, 3643.60it/s]
# 2025-01-22 09:49:27,201 - decision_learning.modeling.train - INFO - epoch: 9, train_loss: -14.987867627825056, val_metric: -0.27580561850284896, test_regret: 0.06473901256162871
# Training Loader: Epoch 10/100: 100%|██████████| 7/7 [00:00<00:00, 1562.12it/s]
# Validation Loader: Epoch 10/100: 100%|██████████| 7/7 [00:00<00:00, 3825.42it/s]
# 2025-01-22 09:49:27,218 - decision_learning.modeling.train - INFO - epoch: 10, train_loss: -15.870483943394252, val_metric: -0.2218268894869726, test_regret: 0.06343188200152416
# Training Loader: Epoch 11/100: 100%|██████████| 7/7 [00:00<00:00, 1672.56it/s]
# Validation Loader: Epoch 11/100: 100%|██████████| 7/7 [00:00<00:00, 3991.32it/s]
# 2025-01-22 09:49:27,234 - decision_learning.modeling.train - INFO - epoch: 11, train_loss: -14.988392557416644, val_metric: -0.2598071909548398, test_regret: 0.06165482154783092
# Training Loader: Epoch 12/100: 100%|██████████| 7/7 [00:00<00:00, 1387.27it/s]
# Validation Loader: Epoch 12/100: 100%|██████████| 7/7 [00:00<00:00, 3797.71it/s]
# 2025-01-22 09:49:27,251 - decision_learning.modeling.train - INFO - epoch: 12, train_loss: -14.980793816702706, val_metric: -0.22701548131572136, test_regret: 0.0550363600294405
# Training Loader: Epoch 13/100: 100%|██████████| 7/7 [00:00<00:00, 1563.46it/s]
# Validation Loader: Epoch 13/100: 100%|██████████| 7/7 [00:00<00:00, 3451.70it/s]
# 2025-01-22 09:49:27,266 - decision_learning.modeling.train - INFO - epoch: 13, train_loss: -15.380612237112862, val_metric: -0.2545784551921806, test_regret: 0.05254592877362372
# Training Loader: Epoch 14/100: 100%|██████████| 7/7 [00:00<00:00, 1622.64it/s]
# Validation Loader: Epoch 14/100: 100%|██████████| 7/7 [00:00<00:00, 3636.38it/s]
# 2025-01-22 09:49:27,282 - decision_learning.modeling.train - INFO - epoch: 14, train_loss: -16.845079149518693, val_metric: -0.24378399325062283, test_regret: 0.048712505243704504
# Training Loader: Epoch 15/100: 100%|██████████| 7/7 [00:00<00:00, 1534.77it/s]
# Validation Loader: Epoch 15/100: 100%|██████████| 7/7 [00:00<00:00, 3466.78it/s]
# 2025-01-22 09:49:27,299 - decision_learning.modeling.train - INFO - epoch: 15, train_loss: -15.421155657087054, val_metric: -0.2208946710541417, test_regret: 0.04834844997126499
# Training Loader: Epoch 16/100: 100%|██████████| 7/7 [00:00<00:00, 1822.93it/s]
# Validation Loader: Epoch 16/100: 100%|██████████| 7/7 [00:00<00:00, 3388.36it/s]
# 2025-01-22 09:49:27,314 - decision_learning.modeling.train - INFO - epoch: 16, train_loss: -16.35670784541539, val_metric: -0.21023424705645774, test_regret: 0.048950636918498075
# Training Loader: Epoch 17/100: 100%|██████████| 7/7 [00:00<00:00, 1913.21it/s]
# Validation Loader: Epoch 17/100: 100%|██████████| 7/7 [00:00<00:00, 2664.74it/s]
# 2025-01-22 09:49:27,331 - decision_learning.modeling.train - INFO - epoch: 17, train_loss: -15.241853169032506, val_metric: -0.2346691107084925, test_regret: 0.04991138526572317
# Training Loader: Epoch 18/100: 100%|██████████| 7/7 [00:00<00:00, 1900.58it/s]
# Validation Loader: Epoch 18/100: 100%|██████████| 7/7 [00:00<00:00, 2807.97it/s]
# 2025-01-22 09:49:27,348 - decision_learning.modeling.train - INFO - epoch: 18, train_loss: -15.161234310695104, val_metric: -0.24604035678507113, test_regret: 0.05024234143725984
# Training Loader: Epoch 19/100: 100%|██████████| 7/7 [00:00<00:00, 1765.39it/s]
# Validation Loader: Epoch 19/100: 100%|██████████| 7/7 [00:00<00:00, 3130.41it/s]
# 2025-01-22 09:49:27,365 - decision_learning.modeling.train - INFO - epoch: 19, train_loss: -16.18293353489467, val_metric: -0.25243501100833216, test_regret: 0.05303745094459329
# Training Loader: Epoch 20/100: 100%|██████████| 7/7 [00:00<00:00, 1514.58it/s]
# Validation Loader: Epoch 20/100: 100%|██████████| 7/7 [00:00<00:00, 3383.28it/s]
# 2025-01-22 09:49:27,382 - decision_learning.modeling.train - INFO - epoch: 20, train_loss: -15.306309291294642, val_metric: -0.21379756776253517, test_regret: 0.05387099715822556
# Training Loader: Epoch 21/100: 100%|██████████| 7/7 [00:00<00:00, 1662.33it/s]
# Validation Loader: Epoch 21/100: 100%|██████████| 7/7 [00:00<00:00, 3533.11it/s]
# 2025-01-22 09:49:27,399 - decision_learning.modeling.train - INFO - epoch: 21, train_loss: -15.161335808890206, val_metric: -0.21735888824942584, test_regret: 0.05208844631583398
# Training Loader: Epoch 22/100: 100%|██████████| 7/7 [00:00<00:00, 1722.41it/s]
# Validation Loader: Epoch 22/100: 100%|██████████| 7/7 [00:00<00:00, 3221.43it/s]
# 2025-01-22 09:49:27,415 - decision_learning.modeling.train - INFO - epoch: 22, train_loss: -15.944459097726005, val_metric: -0.21127512855952604, test_regret: 0.05299702203542821
# Training Loader: Epoch 23/100: 100%|██████████| 7/7 [00:00<00:00, 1723.32it/s]
# Validation Loader: Epoch 23/100: 100%|██████████| 7/7 [00:00<00:00, 3558.37it/s]
# 2025-01-22 09:49:27,431 - decision_learning.modeling.train - INFO - epoch: 23, train_loss: -15.586582047598702, val_metric: -0.21948195810760476, test_regret: 0.05207810306453617
# Training Loader: Epoch 24/100: 100%|██████████| 7/7 [00:00<00:00, 1876.17it/s]
# Validation Loader: Epoch 24/100: 100%|██████████| 7/7 [00:00<00:00, 3181.98it/s]
# 2025-01-22 09:49:27,447 - decision_learning.modeling.train - INFO - epoch: 24, train_loss: -15.78251348223005, val_metric: -0.24334627086580515, test_regret: 0.051535150304509794
# Training Loader: Epoch 25/100: 100%|██████████| 7/7 [00:00<00:00, 1810.12it/s]
# Validation Loader: Epoch 25/100: 100%|██████████| 7/7 [00:00<00:00, 2915.60it/s]
# 2025-01-22 09:49:27,462 - decision_learning.modeling.train - INFO - epoch: 25, train_loss: -15.56982421875, val_metric: -0.2116142122284026, test_regret: 0.051440308716994905
# Training Loader: Epoch 26/100: 100%|██████████| 7/7 [00:00<00:00, 1752.11it/s]
# Validation Loader: Epoch 26/100: 100%|██████████| 7/7 [00:00<00:00, 3101.64it/s]
# 2025-01-22 09:49:27,478 - decision_learning.modeling.train - INFO - epoch: 26, train_loss: -15.358931405203682, val_metric: -0.2381076270406628, test_regret: 0.05089100856597338
# Training Loader: Epoch 27/100: 100%|██████████| 7/7 [00:00<00:00, 1790.80it/s]
# Validation Loader: Epoch 27/100: 100%|██████████| 7/7 [00:00<00:00, 3325.80it/s]
# 2025-01-22 09:49:27,494 - decision_learning.modeling.train - INFO - epoch: 27, train_loss: -15.588814190455846, val_metric: -0.2344548081551604, test_regret: 0.05076776745519147
# Training Loader: Epoch 28/100: 100%|██████████| 7/7 [00:00<00:00, 1794.74it/s]
# Validation Loader: Epoch 28/100: 100%|██████████| 7/7 [00:00<00:00, 3692.17it/s]
# 2025-01-22 09:49:27,510 - decision_learning.modeling.train - INFO - epoch: 28, train_loss: -15.590639386858259, val_metric: -0.22854446281707785, test_regret: 0.050893945366527124
# Training Loader: Epoch 29/100: 100%|██████████| 7/7 [00:00<00:00, 1590.47it/s]
# Validation Loader: Epoch 29/100: 100%|██████████| 7/7 [00:00<00:00, 3833.42it/s]
# 2025-01-22 09:49:27,531 - decision_learning.modeling.train - INFO - epoch: 29, train_loss: -15.477281979152135, val_metric: -0.22148340998755775, test_regret: 0.050472902925098165
# Training Loader: Epoch 30/100: 100%|██████████| 7/7 [00:00<00:00, 1100.45it/s]
# Validation Loader: Epoch 30/100: 100%|██████████| 7/7 [00:00<00:00, 1865.20it/s]
# 2025-01-22 09:49:27,571 - decision_learning.modeling.train - INFO - epoch: 30, train_loss: -15.979453223092216, val_metric: -0.24931711120510508, test_regret: 0.04937263390720073
# Training Loader: Epoch 31/100: 100%|██████████| 7/7 [00:00<00:00, 1227.58it/s]
# Validation Loader: Epoch 31/100: 100%|██████████| 7/7 [00:00<00:00, 3597.61it/s]
# 2025-01-22 09:49:27,594 - decision_learning.modeling.train - INFO - epoch: 31, train_loss: -15.602957316807338, val_metric: -0.21686702039639055, test_regret: 0.0501083843140185
# Training Loader: Epoch 32/100: 100%|██████████| 7/7 [00:00<00:00, 1687.17it/s]
# Validation Loader: Epoch 32/100: 100%|██████████| 7/7 [00:00<00:00, 2942.49it/s]
# 2025-01-22 09:49:27,616 - decision_learning.modeling.train - INFO - epoch: 32, train_loss: -15.576306751796178, val_metric: -0.22687158182608974, test_regret: 0.04979162442036616
# Training Loader: Epoch 33/100: 100%|██████████| 7/7 [00:00<00:00, 1412.16it/s]
# Validation Loader: Epoch 33/100: 100%|██████████| 7/7 [00:00<00:00, 3503.60it/s]
# 2025-01-22 09:49:27,633 - decision_learning.modeling.train - INFO - epoch: 33, train_loss: -15.328828402927943, val_metric: -0.2426705223977662, test_regret: 0.049535373766118246
# Training Loader: Epoch 34/100: 100%|██████████| 7/7 [00:00<00:00, 1492.86it/s]
# Validation Loader: Epoch 34/100: 100%|██████████| 7/7 [00:00<00:00, 3566.15it/s]
# 2025-01-22 09:49:27,650 - decision_learning.modeling.train - INFO - epoch: 34, train_loss: -15.649263109479632, val_metric: -0.24140161590741033, test_regret: 0.04999419746734
# Training Loader: Epoch 35/100: 100%|██████████| 7/7 [00:00<00:00, 1419.60it/s]
# Validation Loader: Epoch 35/100: 100%|██████████| 7/7 [00:00<00:00, 3867.75it/s]
# 2025-01-22 09:49:27,669 - decision_learning.modeling.train - INFO - epoch: 35, train_loss: -15.376139777047294, val_metric: -0.22620804399843492, test_regret: 0.04961871201386035
# Training Loader: Epoch 36/100: 100%|██████████| 7/7 [00:00<00:00, 1533.49it/s]
# Validation Loader: Epoch 36/100: 100%|██████████| 7/7 [00:00<00:00, 4045.77it/s]
# 2025-01-22 09:49:27,685 - decision_learning.modeling.train - INFO - epoch: 36, train_loss: -15.614720753261022, val_metric: -0.20756925734884993, test_regret: 0.049990219025783204
# Training Loader: Epoch 37/100: 100%|██████████| 7/7 [00:00<00:00, 1473.09it/s]
# Validation Loader: Epoch 37/100: 100%|██████████| 7/7 [00:00<00:00, 3713.65it/s]
# 2025-01-22 09:49:27,702 - decision_learning.modeling.train - INFO - epoch: 37, train_loss: -16.325952529907227, val_metric: -0.20842081578005767, test_regret: 0.05041463025266349
# Training Loader: Epoch 38/100: 100%|██████████| 7/7 [00:00<00:00, 1717.77it/s]
# Validation Loader: Epoch 38/100: 100%|██████████| 7/7 [00:00<00:00, 3808.06it/s]
# 2025-01-22 09:49:27,718 - decision_learning.modeling.train - INFO - epoch: 38, train_loss: -16.08766978127616, val_metric: -0.22453688412628192, test_regret: 0.050084283737232276
# Training Loader: Epoch 39/100: 100%|██████████| 7/7 [00:00<00:00, 1616.57it/s]
# Validation Loader: Epoch 39/100: 100%|██████████| 7/7 [00:00<00:00, 3884.64it/s]
# 2025-01-22 09:49:27,734 - decision_learning.modeling.train - INFO - epoch: 39, train_loss: -16.012824739728654, val_metric: -0.2388076107225689, test_regret: 0.05009804803021903
# Training Loader: Epoch 40/100: 100%|██████████| 7/7 [00:00<00:00, 1378.47it/s]
# Validation Loader: Epoch 40/100: 100%|██████████| 7/7 [00:00<00:00, 3893.40it/s]
# 2025-01-22 09:49:27,752 - decision_learning.modeling.train - INFO - epoch: 40, train_loss: -15.261356898716517, val_metric: -0.21258759796309998, test_regret: 0.049862348012348956
# Training Loader: Epoch 41/100: 100%|██████████| 7/7 [00:00<00:00, 1499.96it/s]
# Validation Loader: Epoch 41/100: 100%|██████████| 7/7 [00:00<00:00, 3391.10it/s]
# 2025-01-22 09:49:27,768 - decision_learning.modeling.train - INFO - epoch: 41, train_loss: -15.644728796822685, val_metric: -0.24074128773379935, test_regret: 0.04968540839179793
# Training Loader: Epoch 42/100: 100%|██████████| 7/7 [00:00<00:00, 1407.89it/s]
# Validation Loader: Epoch 42/100: 100%|██████████| 7/7 [00:00<00:00, 3894.95it/s]
# 2025-01-22 09:49:27,784 - decision_learning.modeling.train - INFO - epoch: 42, train_loss: -15.157720565795898, val_metric: -0.25672506251334754, test_regret: 0.04983095594854141
# Training Loader: Epoch 43/100: 100%|██████████| 7/7 [00:00<00:00, 1559.72it/s]
# Validation Loader: Epoch 43/100: 100%|██████████| 7/7 [00:00<00:00, 3573.53it/s]
# 2025-01-22 09:49:27,802 - decision_learning.modeling.train - INFO - epoch: 43, train_loss: -15.233671460832868, val_metric: -0.232751365675668, test_regret: 0.04996832366222417
# Training Loader: Epoch 44/100: 100%|██████████| 7/7 [00:00<00:00, 1572.75it/s]
# Validation Loader: Epoch 44/100: 100%|██████████| 7/7 [00:00<00:00, 3344.74it/s]
# 2025-01-22 09:49:27,819 - decision_learning.modeling.train - INFO - epoch: 44, train_loss: -15.488373483930316, val_metric: -0.22257364573614058, test_regret: 0.04983603177108803
# Training Loader: Epoch 45/100: 100%|██████████| 7/7 [00:00<00:00, 1366.16it/s]
# Validation Loader: Epoch 45/100: 100%|██████████| 7/7 [00:00<00:00, 3634.13it/s]
# 2025-01-22 09:49:27,844 - decision_learning.modeling.train - INFO - epoch: 45, train_loss: -16.34681647164481, val_metric: -0.21189333583840245, test_regret: 0.04967335810340482
# Training Loader: Epoch 46/100: 100%|██████████| 7/7 [00:00<00:00, 1336.13it/s]
# Validation Loader: Epoch 46/100: 100%|██████████| 7/7 [00:00<00:00, 2796.74it/s]
# 2025-01-22 09:49:27,862 - decision_learning.modeling.train - INFO - epoch: 46, train_loss: -15.923172678266253, val_metric: -0.2331610152167835, test_regret: 0.049774257930733416
# Training Loader: Epoch 47/100: 100%|██████████| 7/7 [00:00<00:00, 1521.41it/s]
# Validation Loader: Epoch 47/100: 100%|██████████| 7/7 [00:00<00:00, 3009.44it/s]
# 2025-01-22 09:49:27,881 - decision_learning.modeling.train - INFO - epoch: 47, train_loss: -16.008853912353516, val_metric: -0.23315080479558611, test_regret: 0.04998544628941473
# Training Loader: Epoch 48/100: 100%|██████████| 7/7 [00:00<00:00, 1711.56it/s]
# Validation Loader: Epoch 48/100: 100%|██████████| 7/7 [00:00<00:00, 2636.51it/s]
# 2025-01-22 09:49:27,899 - decision_learning.modeling.train - INFO - epoch: 48, train_loss: -15.769592830113002, val_metric: -0.19930383998529005, test_regret: 0.050059650146822426
# Training Loader: Epoch 49/100: 100%|██████████| 7/7 [00:00<00:00, 1411.88it/s]
# Validation Loader: Epoch 49/100: 100%|██████████| 7/7 [00:00<00:00, 3619.79it/s]
# 2025-01-22 09:49:27,916 - decision_learning.modeling.train - INFO - epoch: 49, train_loss: -15.7277649470738, val_metric: -0.22391246686458158, test_regret: 0.049942637979563755
# Training Loader: Epoch 50/100: 100%|██████████| 7/7 [00:00<00:00, 1414.47it/s]
# Validation Loader: Epoch 50/100: 100%|██████████| 7/7 [00:00<00:00, 3436.34it/s]
# 2025-01-22 09:49:27,935 - decision_learning.modeling.train - INFO - epoch: 50, train_loss: -16.288909912109375, val_metric: -0.24506031915865975, test_regret: 0.04982277610548069
# Training Loader: Epoch 51/100: 100%|██████████| 7/7 [00:00<00:00, 1069.51it/s]
# Validation Loader: Epoch 51/100: 100%|██████████| 7/7 [00:00<00:00, 2730.16it/s]
# 2025-01-22 09:49:27,954 - decision_learning.modeling.train - INFO - epoch: 51, train_loss: -15.498719760349818, val_metric: -0.2094699540018619, test_regret: 0.04991124591575621
# Training Loader: Epoch 52/100: 100%|██████████| 7/7 [00:00<00:00, 1511.54it/s]
# Validation Loader: Epoch 52/100: 100%|██████████| 7/7 [00:00<00:00, 2422.25it/s]
# 2025-01-22 09:49:27,973 - decision_learning.modeling.train - INFO - epoch: 52, train_loss: -15.15487698146275, val_metric: -0.23747062700477617, test_regret: 0.04982277610548069
# Training Loader: Epoch 53/100: 100%|██████████| 7/7 [00:00<00:00, 1775.31it/s]
# Validation Loader: Epoch 53/100: 100%|██████████| 7/7 [00:00<00:00, 2995.32it/s]
# 2025-01-22 09:49:27,991 - decision_learning.modeling.train - INFO - epoch: 53, train_loss: -15.56476606641497, val_metric: -0.21761091586695422, test_regret: 0.04982277610548069
# Training Loader: Epoch 54/100: 100%|██████████| 7/7 [00:00<00:00, 1752.11it/s]
# Validation Loader: Epoch 54/100: 100%|██████████| 7/7 [00:00<00:00, 3334.86it/s]
# 2025-01-22 09:49:28,007 - decision_learning.modeling.train - INFO - epoch: 54, train_loss: -15.295069830758232, val_metric: -0.20267500009926526, test_regret: 0.04979046084814202
# Training Loader: Epoch 55/100: 100%|██████████| 7/7 [00:00<00:00, 1770.82it/s]
# Validation Loader: Epoch 55/100: 100%|██████████| 7/7 [00:00<00:00, 3336.38it/s]
# 2025-01-22 09:49:28,024 - decision_learning.modeling.train - INFO - epoch: 55, train_loss: -15.322801181248256, val_metric: -0.2245602355223689, test_regret: 0.049664732340449824
# Training Loader: Epoch 56/100: 100%|██████████| 7/7 [00:00<00:00, 1531.49it/s]
# Validation Loader: Epoch 56/100: 100%|██████████| 7/7 [00:00<00:00, 3160.06it/s]
# 2025-01-22 09:49:28,042 - decision_learning.modeling.train - INFO - epoch: 56, train_loss: -15.709510122026716, val_metric: -0.2344626694817315, test_regret: 0.049664732340449824
# Training Loader: Epoch 57/100: 100%|██████████| 7/7 [00:00<00:00, 1697.80it/s]
# Validation Loader: Epoch 57/100: 100%|██████████| 7/7 [00:00<00:00, 3626.95it/s]
# 2025-01-22 09:49:28,060 - decision_learning.modeling.train - INFO - epoch: 57, train_loss: -15.441547530038017, val_metric: -0.21408925088835867, test_regret: 0.049664732340449824
# Training Loader: Epoch 58/100: 100%|██████████| 7/7 [00:00<00:00, 1571.32it/s]
# Validation Loader: Epoch 58/100: 100%|██████████| 7/7 [00:00<00:00, 2181.29it/s]
# 2025-01-22 09:49:28,079 - decision_learning.modeling.train - INFO - epoch: 58, train_loss: -15.879937171936035, val_metric: -0.22175248598489866, test_regret: 0.049664732340449824
# Training Loader: Epoch 59/100: 100%|██████████| 7/7 [00:00<00:00, 1678.68it/s]
# Validation Loader: Epoch 59/100: 100%|██████████| 7/7 [00:00<00:00, 2669.59it/s]
# 2025-01-22 09:49:28,097 - decision_learning.modeling.train - INFO - epoch: 59, train_loss: -15.144911357334681, val_metric: -0.21248151657111522, test_regret: 0.049664732340449824
# Training Loader: Epoch 60/100: 100%|██████████| 7/7 [00:00<00:00, 1689.11it/s]
# Validation Loader: Epoch 60/100: 100%|██████████| 7/7 [00:00<00:00, 1915.71it/s]
# 2025-01-22 09:49:28,116 - decision_learning.modeling.train - INFO - epoch: 60, train_loss: -15.175251007080078, val_metric: -0.218074989976639, test_regret: 0.049664732340449824
# Training Loader: Epoch 61/100: 100%|██████████| 7/7 [00:00<00:00, 1483.36it/s]
# Validation Loader: Epoch 61/100: 100%|██████████| 7/7 [00:00<00:00, 3576.58it/s]
# 2025-01-22 09:49:28,135 - decision_learning.modeling.train - INFO - epoch: 61, train_loss: -15.294464111328125, val_metric: -0.23197593186536933, test_regret: 0.049664732340449824
# Training Loader: Epoch 62/100: 100%|██████████| 7/7 [00:00<00:00, 1797.27it/s]
# Validation Loader: Epoch 62/100: 100%|██████████| 7/7 [00:00<00:00, 3448.86it/s]
# 2025-01-22 09:49:28,153 - decision_learning.modeling.train - INFO - epoch: 62, train_loss: -15.377325466700963, val_metric: -0.22174608993517364, test_regret: 0.049664732340449824
# Training Loader: Epoch 63/100: 100%|██████████| 7/7 [00:00<00:00, 1724.13it/s]
# Validation Loader: Epoch 63/100: 100%|██████████| 7/7 [00:00<00:00, 3242.42it/s]
# 2025-01-22 09:49:28,171 - decision_learning.modeling.train - INFO - epoch: 63, train_loss: -15.268956865583148, val_metric: -0.19859743699529628, test_regret: 0.049664732340449824
# Training Loader: Epoch 64/100: 100%|██████████| 7/7 [00:00<00:00, 1575.88it/s]
# Validation Loader: Epoch 64/100: 100%|██████████| 7/7 [00:00<00:00, 3000.52it/s]
# 2025-01-22 09:49:28,189 - decision_learning.modeling.train - INFO - epoch: 64, train_loss: -15.935048648289271, val_metric: -0.23446808868022578, test_regret: 0.04957626253017431
# Training Loader: Epoch 65/100: 100%|██████████| 7/7 [00:00<00:00, 1713.26it/s]
# Validation Loader: Epoch 65/100: 100%|██████████| 7/7 [00:00<00:00, 3219.67it/s]
# 2025-01-22 09:49:28,206 - decision_learning.modeling.train - INFO - epoch: 65, train_loss: -15.439205578395299, val_metric: -0.24280753741205746, test_regret: 0.04957626253017431
# Training Loader: Epoch 66/100: 100%|██████████| 7/7 [00:00<00:00, 1624.17it/s]
# Validation Loader: Epoch 66/100: 100%|██████████| 7/7 [00:00<00:00, 3517.87it/s]
# 2025-01-22 09:49:28,223 - decision_learning.modeling.train - INFO - epoch: 66, train_loss: -15.666664804731097, val_metric: -0.23323979129103312, test_regret: 0.04957626253017431
# Training Loader: Epoch 67/100: 100%|██████████| 7/7 [00:00<00:00, 1794.30it/s]
# Validation Loader: Epoch 67/100: 100%|██████████| 7/7 [00:00<00:00, 3416.35it/s]
# 2025-01-22 09:49:28,256 - decision_learning.modeling.train - INFO - epoch: 67, train_loss: -15.411931991577148, val_metric: -0.21538129944953782, test_regret: 0.04957626253017431
# Training Loader: Epoch 68/100: 100%|██████████| 7/7 [00:00<00:00, 1410.39it/s]
# Validation Loader: Epoch 68/100: 100%|██████████| 7/7 [00:00<00:00, 1423.31it/s]
# 2025-01-22 09:49:28,289 - decision_learning.modeling.train - INFO - epoch: 68, train_loss: -15.541825294494629, val_metric: -0.2347632838188074, test_regret: 0.04957626253017431
# Training Loader: Epoch 69/100: 100%|██████████| 7/7 [00:00<00:00, 1602.54it/s]
# Validation Loader: Epoch 69/100: 100%|██████████| 7/7 [00:00<00:00, 2667.65it/s]
# 2025-01-22 09:49:28,311 - decision_learning.modeling.train - INFO - epoch: 69, train_loss: -15.939163752964564, val_metric: -0.21370281319315432, test_regret: 0.04957626253017431
# Training Loader: Epoch 70/100: 100%|██████████| 7/7 [00:00<00:00, 1510.29it/s]
# Validation Loader: Epoch 70/100: 100%|██████████| 7/7 [00:00<00:00, 2807.70it/s]
# 2025-01-22 09:49:28,332 - decision_learning.modeling.train - INFO - epoch: 70, train_loss: -15.188298225402832, val_metric: -0.23895767367829918, test_regret: 0.04957626253017431
# Training Loader: Epoch 71/100: 100%|██████████| 7/7 [00:00<00:00, 1404.72it/s]
# Validation Loader: Epoch 71/100: 100%|██████████| 7/7 [00:00<00:00, 2657.51it/s]
# 2025-01-22 09:49:28,350 - decision_learning.modeling.train - INFO - epoch: 71, train_loss: -15.54167434147426, val_metric: -0.25083876632223107, test_regret: 0.04957626253017431
# Training Loader: Epoch 72/100: 100%|██████████| 7/7 [00:00<00:00, 1727.47it/s]
# Validation Loader: Epoch 72/100: 100%|██████████| 7/7 [00:00<00:00, 3105.58it/s]
# 2025-01-22 09:49:28,369 - decision_learning.modeling.train - INFO - epoch: 72, train_loss: -15.468765667506627, val_metric: -0.23974324813470735, test_regret: 0.04957626253017431
# Training Loader: Epoch 73/100: 100%|██████████| 7/7 [00:00<00:00, 1294.60it/s]
# Validation Loader: Epoch 73/100: 100%|██████████| 7/7 [00:00<00:00, 3244.93it/s]
# 2025-01-22 09:49:28,389 - decision_learning.modeling.train - INFO - epoch: 73, train_loss: -15.24444934300014, val_metric: -0.22045783248710424, test_regret: 0.04957626253017431
# Training Loader: Epoch 74/100: 100%|██████████| 7/7 [00:00<00:00, 1393.59it/s]
# Validation Loader: Epoch 74/100: 100%|██████████| 7/7 [00:00<00:00, 3616.22it/s]
# 2025-01-22 09:49:28,409 - decision_learning.modeling.train - INFO - epoch: 74, train_loss: -15.167149543762207, val_metric: -0.23087678816389676, test_regret: 0.04957626253017431
# Training Loader: Epoch 75/100: 100%|██████████| 7/7 [00:00<00:00, 1551.48it/s]
# Validation Loader: Epoch 75/100: 100%|██████████| 7/7 [00:00<00:00, 3393.06it/s]
# 2025-01-22 09:49:28,429 - decision_learning.modeling.train - INFO - epoch: 75, train_loss: -15.297545296805245, val_metric: -0.2594951335033468, test_regret: 0.04957626253017431
# Training Loader: Epoch 76/100: 100%|██████████| 7/7 [00:00<00:00, 1387.53it/s]
# Validation Loader: Epoch 76/100: 100%|██████████| 7/7 [00:00<00:00, 3101.64it/s]
# 2025-01-22 09:49:28,447 - decision_learning.modeling.train - INFO - epoch: 76, train_loss: -15.979349545070104, val_metric: -0.20290048992502546, test_regret: 0.04957626253017431
# Training Loader: Epoch 77/100: 100%|██████████| 7/7 [00:00<00:00, 1711.56it/s]
# Validation Loader: Epoch 77/100: 100%|██████████| 7/7 [00:00<00:00, 2664.50it/s]
# 2025-01-22 09:49:28,467 - decision_learning.modeling.train - INFO - epoch: 77, train_loss: -15.987824848720006, val_metric: -0.23557265158019267, test_regret: 0.04957626253017431
# Training Loader: Epoch 78/100: 100%|██████████| 7/7 [00:00<00:00, 1758.83it/s]
# Validation Loader: Epoch 78/100: 100%|██████████| 7/7 [00:00<00:00, 3076.94it/s]
# 2025-01-22 09:49:28,485 - decision_learning.modeling.train - INFO - epoch: 78, train_loss: -15.138689041137695, val_metric: -0.22634159351669333, test_regret: 0.04957626253017431
# Training Loader: Epoch 79/100: 100%|██████████| 7/7 [00:00<00:00, 1452.25it/s]
# Validation Loader: Epoch 79/100: 100%|██████████| 7/7 [00:00<00:00, 2936.31it/s]
# 2025-01-22 09:49:28,504 - decision_learning.modeling.train - INFO - epoch: 79, train_loss: -16.019833292279923, val_metric: -0.2394871735620802, test_regret: 0.04957626253017431
# Training Loader: Epoch 80/100: 100%|██████████| 7/7 [00:00<00:00, 1446.95it/s]
# Validation Loader: Epoch 80/100: 100%|██████████| 7/7 [00:00<00:00, 3068.90it/s]
# 2025-01-22 09:49:28,528 - decision_learning.modeling.train - INFO - epoch: 80, train_loss: -15.607831818716866, val_metric: -0.24058036312271786, test_regret: 0.04957626253017431
# Training Loader: Epoch 81/100: 100%|██████████| 7/7 [00:00<00:00, 1186.41it/s]
# Validation Loader: Epoch 81/100: 100%|██████████| 7/7 [00:00<00:00, 2219.54it/s]
# 2025-01-22 09:49:28,551 - decision_learning.modeling.train - INFO - epoch: 81, train_loss: -15.29391438620431, val_metric: -0.2101380272102308, test_regret: 0.04957626253017431
# Training Loader: Epoch 82/100: 100%|██████████| 7/7 [00:00<00:00, 1259.01it/s]
# Validation Loader: Epoch 82/100: 100%|██████████| 7/7 [00:00<00:00, 2952.25it/s]
# 2025-01-22 09:49:28,570 - decision_learning.modeling.train - INFO - epoch: 82, train_loss: -15.885087421962194, val_metric: -0.23655220078098868, test_regret: 0.04957626253017431
# Training Loader: Epoch 83/100: 100%|██████████| 7/7 [00:00<00:00, 1204.81it/s]
# Validation Loader: Epoch 83/100: 100%|██████████| 7/7 [00:00<00:00, 2640.30it/s]
# 2025-01-22 09:49:28,590 - decision_learning.modeling.train - INFO - epoch: 83, train_loss: -16.39834008898054, val_metric: -0.21317833711570275, test_regret: 0.04957626253017431
# Training Loader: Epoch 84/100: 100%|██████████| 7/7 [00:00<00:00, 1891.88it/s]
# Validation Loader: Epoch 84/100: 100%|██████████| 7/7 [00:00<00:00, 3034.32it/s]
# 2025-01-22 09:49:28,608 - decision_learning.modeling.train - INFO - epoch: 84, train_loss: -16.28435720716204, val_metric: -0.20944060194821473, test_regret: 0.04957626253017431
# Training Loader: Epoch 85/100: 100%|██████████| 7/7 [00:00<00:00, 1725.85it/s]
# Validation Loader: Epoch 85/100: 100%|██████████| 7/7 [00:00<00:00, 3525.05it/s]
# 2025-01-22 09:49:28,625 - decision_learning.modeling.train - INFO - epoch: 85, train_loss: -16.579396111624582, val_metric: -0.24715503707278486, test_regret: 0.04957626253017431
# Training Loader: Epoch 86/100: 100%|██████████| 7/7 [00:00<00:00, 1666.30it/s]
# Validation Loader: Epoch 86/100: 100%|██████████| 7/7 [00:00<00:00, 4050.79it/s]
# 2025-01-22 09:49:28,643 - decision_learning.modeling.train - INFO - epoch: 86, train_loss: -15.665335246494838, val_metric: -0.23339752950643342, test_regret: 0.04957626253017431
# Training Loader: Epoch 87/100: 100%|██████████| 7/7 [00:00<00:00, 1764.54it/s]
# Validation Loader: Epoch 87/100: 100%|██████████| 7/7 [00:00<00:00, 3286.34it/s]
# 2025-01-22 09:49:28,661 - decision_learning.modeling.train - INFO - epoch: 87, train_loss: -16.360147067478724, val_metric: -0.23339936691708169, test_regret: 0.04957626253017431
# Training Loader: Epoch 88/100: 100%|██████████| 7/7 [00:00<00:00, 1733.49it/s]
# Validation Loader: Epoch 88/100: 100%|██████████| 7/7 [00:00<00:00, 3480.75it/s]
# 2025-01-22 09:49:28,677 - decision_learning.modeling.train - INFO - epoch: 88, train_loss: -15.803115844726562, val_metric: -0.20244299793196682, test_regret: 0.04957626253017431
# Training Loader: Epoch 89/100: 100%|██████████| 7/7 [00:00<00:00, 1578.33it/s]
# Validation Loader: Epoch 89/100: 100%|██████████| 7/7 [00:00<00:00, 3122.42it/s]
# 2025-01-22 09:49:28,696 - decision_learning.modeling.train - INFO - epoch: 89, train_loss: -15.933337620326451, val_metric: -0.23583688983810516, test_regret: 0.04957626253017431
# Training Loader: Epoch 90/100: 100%|██████████| 7/7 [00:00<00:00, 1837.30it/s]
# Validation Loader: Epoch 90/100: 100%|██████████| 7/7 [00:00<00:00, 2522.56it/s]
# 2025-01-22 09:49:28,713 - decision_learning.modeling.train - INFO - epoch: 90, train_loss: -15.642818314688546, val_metric: -0.22274643211216663, test_regret: 0.04957626253017431
# Training Loader: Epoch 91/100: 100%|██████████| 7/7 [00:00<00:00, 1746.07it/s]
# Validation Loader: Epoch 91/100: 100%|██████████| 7/7 [00:00<00:00, 3102.62it/s]
# 2025-01-22 09:49:28,731 - decision_learning.modeling.train - INFO - epoch: 91, train_loss: -15.413694790431432, val_metric: -0.24707193494308488, test_regret: 0.04957626253017431
# Training Loader: Epoch 92/100: 100%|██████████| 7/7 [00:00<00:00, 1600.36it/s]
# Validation Loader: Epoch 92/100: 100%|██████████| 7/7 [00:00<00:00, 3006.67it/s]
# 2025-01-22 09:49:28,750 - decision_learning.modeling.train - INFO - epoch: 92, train_loss: -15.19742066519601, val_metric: -0.2107693056889089, test_regret: 0.04957626253017431
# Training Loader: Epoch 93/100: 100%|██████████| 7/7 [00:00<00:00, 1382.56it/s]
# Validation Loader: Epoch 93/100: 100%|██████████| 7/7 [00:00<00:00, 3625.15it/s]
# 2025-01-22 09:49:28,768 - decision_learning.modeling.train - INFO - epoch: 93, train_loss: -15.566276686532158, val_metric: -0.2286965027336322, test_regret: 0.04957626253017431
# Training Loader: Epoch 94/100: 100%|██████████| 7/7 [00:00<00:00, 1487.49it/s]
# Validation Loader: Epoch 94/100: 100%|██████████| 7/7 [00:00<00:00, 3474.16it/s]
# 2025-01-22 09:49:28,785 - decision_learning.modeling.train - INFO - epoch: 94, train_loss: -15.201182229178292, val_metric: -0.25185192385703675, test_regret: 0.04957626253017431
# Training Loader: Epoch 95/100: 100%|██████████| 7/7 [00:00<00:00, 1644.64it/s]
# Validation Loader: Epoch 95/100: 100%|██████████| 7/7 [00:00<00:00, 1116.61it/s]
# 2025-01-22 09:49:28,824 - decision_learning.modeling.train - INFO - epoch: 95, train_loss: -15.958711896623884, val_metric: -0.22450736926409628, test_regret: 0.04957626253017431
# Training Loader: Epoch 96/100: 100%|██████████| 7/7 [00:00<00:00, 894.93it/s]
# Validation Loader: Epoch 96/100: 100%|██████████| 7/7 [00:00<00:00, 1389.70it/s]
# 2025-01-22 09:49:28,856 - decision_learning.modeling.train - INFO - epoch: 96, train_loss: -15.10373592376709, val_metric: -0.22404694671734546, test_regret: 0.04957626253017431
# Training Loader: Epoch 97/100: 100%|██████████| 7/7 [00:00<00:00, 1520.70it/s]
# Validation Loader: Epoch 97/100: 100%|██████████| 7/7 [00:00<00:00, 2535.42it/s]
# 2025-01-22 09:49:28,876 - decision_learning.modeling.train - INFO - epoch: 97, train_loss: -16.278469358171737, val_metric: -0.22540823542409325, test_regret: 0.04957626253017431
# Training Loader: Epoch 98/100: 100%|██████████| 7/7 [00:00<00:00, 1727.88it/s]
# Validation Loader: Epoch 98/100: 100%|██████████| 7/7 [00:00<00:00, 2915.31it/s]
# 2025-01-22 09:49:28,895 - decision_learning.modeling.train - INFO - epoch: 98, train_loss: -15.504837717328753, val_metric: -0.25417978359822946, test_regret: 0.04957626253017431
# Training Loader: Epoch 99/100: 100%|██████████| 7/7 [00:00<00:00, 1752.63it/s]
# Validation Loader: Epoch 99/100: 100%|██████████| 7/7 [00:00<00:00, 2748.30it/s]
# 2025-01-22 09:49:28,914 - decision_learning.modeling.train - INFO - epoch: 99, train_loss: -15.517656871250697, val_metric: -0.23697396792903777, test_regret: 0.04957626253017431
# Training Loader: Epoch 100/100: 100%|██████████| 7/7 [00:00<00:00, 1711.06it/s]
# Validation Loader: Epoch 100/100: 100%|██████████| 7/7 [00:00<00:00, 2987.40it/s]
# 2025-01-22 09:49:28,932 - decision_learning.modeling.train - INFO - epoch: 100, train_loss: -16.090511049543107, val_metric: -0.2332410472426155, test_regret: 0.04957626253017431
# 2025-01-22 09:49:28,934 - decision_learning.utils - INFO - Function 'train' took 1.8917100429534912 seconds to run.

# %%
metrics
# Out:
#     epoch  train_loss  val_metric  test_regret
# 0       0   17.036830   -0.338152     0.226994
# 1       1   -2.402540   -0.355240     0.182704
# 2       2   -9.259743   -0.204008     0.111312
# 3       3  -11.247399   -0.261308     0.152418
# 4       4  -13.196653   -0.300556     0.099896
# ..    ...         ...         ...          ...
# 95     95  -15.103736   -0.224047     0.049576
# 96     96  -16.278469   -0.225408     0.049576
# 97     97  -15.504838   -0.254180     0.049576
# 98     98  -15.517657   -0.236974     0.049576
# 99     99  -16.090511   -0.233241     0.049576
#
# [100 rows x 4 columns]

# %%
trained_model
# Out:
# LinearRegression(
#   (linear): Linear(in_features=6, out_features=40, bias=True)
# )

# %%
true_cost = train_dataset.data['true_cost']
pred = pred_model(train_dataset.data['X'])

# %%
loss_fn.reduction = 'none'
loss = loss_fn(pred_cost=pred, true_cost=true_cost)

# %%
loss_fn.alpha*torch.sum(pred[0:10]*pred[0:10], axis=1), torch.sum(pred[0:10]*true_cost[0:10], axis=1), loss_fn.alpha*torch.sum(pred[0:10]*pred[0:10], axis=1) - torch.sum(pred[0:10]*true_cost[0:10], axis=1)
# Out:
# (tensor([20.2643, 31.2862, 15.0194,  8.9187, 23.7875,  9.6625, 10.1521, 11.1846,
#          13.2788, 33.2027], grad_fn=<MulBackward0>),
#  tensor([35.8214, 83.6610, 27.1818, 17.7569, 47.2153, 19.6156, 20.3317, 21.8667,
#          23.6769, 76.5764], grad_fn=<SumBackward1>),
#  tensor([-15.5571, -52.3748, -12.1624,  -8.8382, -23.4278,  -9.9531, -10.1796,
#          -10.6821, -10.3982, -43.3737], grad_fn=<SubBackward0>))

# %%
cos = nn.CosineSimilarity(dim=1, eps=1e-6)
output = cos(pred, true_cost)

# %%
output.mean()
# Out:
# tensor(0.9686, grad_fn=<MeanBackward0>)

# %%
pred_mag = torch.norm(pred, dim=1)
true_mag = torch.norm(true_cost, dim=1)

torch.sum(pred*true_cost, axis=1)/(pred_mag*true_mag)
# Out:
# tensor([0.9808, 0.9629, 0.9657, 0.9688, 0.9720, 0.9775, 0.9768, 0.9739, 0.9846,
#         0.9714, 0.9668, 0.9714, 0.9853, 0.9551, 0.9825, 0.9813, 0.9704, 0.9764,
#         0.9806, 0.6674, 0.9758, 0.9731, 0.9824, 0.9794, 0.9495, 0.9517, 0.9810,
#         0.9503, 0.9820, 0.9830, 0.9771, 0.9802, 0.9849, 0.9769, 0.9810, 0.9774,
#         0.9321, 0.9546, 0.9775, 0.9805, 0.9753, 0.9277, 0.9782, 0.9842, 0.9814,
#         0.9762, 0.9556, 0.9763, 0.9768, 0.9855, 0.9786, 0.9784, 0.9823, 0.9563,
#         0.9826, 0.9810, 0.9641, 0.9823, 0.9703, 0.9859, 0.9810, 0.9807, 0.9722,
#         0.9786, 0.9785, 0.9777, 0.9639, 0.9819, 0.9782, 0.9754, 0.9111, 0.9047,
#         0.9006, 0.9767, 0.9805, 0.9737, 0.9795, 0.9848, 0.9840, 0.9834, 0.9761,
#         0.9700, 0.9359, 0.9802, 0.9782, 0.9816, 0.9730, 0.9767, 0.9784, 0.9453,
#         0.9794, 0.9041, 0.9746, 0.9778, 0.9823, 0.9866, 0.9787, 0.9643, 0.9820,
#         0.9708, 0.9737, 0.9601, 0.9001, 0.9823, 0.9614, 0.8899, 0.9755, 0.9807,
#         0.9708, 0.9756, 0.9852, 0.9842, 0.9855, 0.9826, 0.8249, 0.9759, 0.9795,
#         0.9787, 0.9795, 0.9820, 0.8620, 0.9842, 0.9836, 0.9851, 0.9707, 0.9707,
#         0.9831, 0.9714, 0.9600, 0.9764, 0.9831, 0.9743, 0.9737, 0.9784, 0.9804,
#         0.9840, 0.9836, 0.9745, 0.9861, 0.9656, 0.9765, 0.9841, 0.9701, 0.9757,
#         0.9706, 0.9777, 0.9797, 0.9828, 0.9762, 0.9685, 0.9681, 0.9759, 0.9882,
#         0.8104, 0.9690, 0.9837, 0.9695, 0.9867, 0.9694, 0.9735, 0.9587, 0.9703,
#         0.9652, 0.9556, 0.9597, 0.9669, 0.9701, 0.9796, 0.9866, 0.9352, 0.9672,
#         0.9803, 0.9767, 0.9838, 0.9780, 0.9680, 0.9749, 0.9593, 0.9811, 0.9846,
#         0.9828, 0.9752, 0.9873, 0.9623, 0.9776, 0.9431, 0.9710, 0.9781, 0.9724,
#         0.9830, 0.9701, 0.9828, 0.9778, 0.9795, 0.9624, 0.9769, 0.9797, 0.9740,
#         0.9842, 0.9631], grad_fn=<DivBackward0>)

# %% [markdown]
# # Cosine

# %%
# Prediction Model
pred_model = LinearRegression(input_dim=train_dict['X'].shape[1],
                 output_dim=train_dict['true_cost'].shape[1])

# optimization solver
optmodel = partial(shortest_path_solver,size=5)

# loss function
loss_fn = get_loss_function('Cosine')()

# training, validation data
train_data_dict = train_dict
train_data_dict.update({'input2':train_dict['true_cost'], 
                       'target':torch.ones(train_dict['true_cost'].shape[0])}) # extra input key needed for loss function

val_data_dict = val_dict

# %%
metrics, trained_model = train(pred_model=pred_model,
                optmodel=optmodel,
                loss_fn=loss_fn,
                train_data_dict=train_data_dict,
                val_data_dict=val_data_dict,
                test_data_dict=final_data_test, # test data dictionary
                num_epochs=100,
                lr=0.1,
                scheduler_params={'step_size': 10, 'gamma': 0.1},
                minimization=False)
# Out:
# 2025-01-22 09:54:44,766 - decision_learning.modeling.train - INFO - Training on device: cpu
# Training Loader: Epoch 1/100: 100%|██████████| 7/7 [00:00<00:00, 486.89it/s]
# Validation Loader: Epoch 1/100: 100%|██████████| 7/7 [00:00<00:00, 2335.17it/s]
# 2025-01-22 09:54:44,800 - decision_learning.modeling.train - INFO - epoch: 1, train_loss: 0.5147819327456611, val_metric: -0.3434356341429162, test_regret: 0.1953900160317956
# Training Loader: Epoch 2/100: 100%|██████████| 7/7 [00:00<00:00, 1415.63it/s]
# Validation Loader: Epoch 2/100: 100%|██████████| 7/7 [00:00<00:00, 3743.00it/s]
# 2025-01-22 09:54:44,816 - decision_learning.modeling.train - INFO - epoch: 2, train_loss: 0.05418300947972706, val_metric: -0.2298140437999502, test_regret: 0.145180021205617
# Training Loader: Epoch 3/100: 100%|██████████| 7/7 [00:00<00:00, 1503.41it/s]
# Validation Loader: Epoch 3/100: 100%|██████████| 7/7 [00:00<00:00, 3783.52it/s]
# 2025-01-22 09:54:44,832 - decision_learning.modeling.train - INFO - epoch: 3, train_loss: 0.04024487414530346, val_metric: -0.1952224625098487, test_regret: 0.11774342014530595
# Training Loader: Epoch 4/100: 100%|██████████| 7/7 [00:00<00:00, 1589.35it/s]
# Validation Loader: Epoch 4/100: 100%|██████████| 7/7 [00:00<00:00, 4151.60it/s]
# 2025-01-22 09:54:44,847 - decision_learning.modeling.train - INFO - epoch: 4, train_loss: 0.034377756395510266, val_metric: -0.18650018112902136, test_regret: 0.09268569024101043
# Training Loader: Epoch 5/100: 100%|██████████| 7/7 [00:00<00:00, 1663.93it/s]
# Validation Loader: Epoch 5/100: 100%|██████████| 7/7 [00:00<00:00, 3458.61it/s]
# 2025-01-22 09:54:44,862 - decision_learning.modeling.train - INFO - epoch: 5, train_loss: 0.029705035367182324, val_metric: -0.21800865712639989, test_regret: 0.07617568731021371
# Training Loader: Epoch 6/100: 100%|██████████| 7/7 [00:00<00:00, 1601.75it/s]
# Validation Loader: Epoch 6/100: 100%|██████████| 7/7 [00:00<00:00, 3381.72it/s]
# 2025-01-22 09:54:44,878 - decision_learning.modeling.train - INFO - epoch: 6, train_loss: 0.027034292529736246, val_metric: -0.1743036934585581, test_regret: 0.06592918669446138
# Training Loader: Epoch 7/100: 100%|██████████| 7/7 [00:00<00:00, 1590.21it/s]
# Validation Loader: Epoch 7/100: 100%|██████████| 7/7 [00:00<00:00, 3841.94it/s]
# 2025-01-22 09:54:44,893 - decision_learning.modeling.train - INFO - epoch: 7, train_loss: 0.02623484336904117, val_metric: -0.20348206528274948, test_regret: 0.05251486418223853
# Training Loader: Epoch 8/100: 100%|██████████| 7/7 [00:00<00:00, 1530.77it/s]
# Validation Loader: Epoch 8/100: 100%|██████████| 7/7 [00:00<00:00, 3733.49it/s]
# 2025-01-22 09:54:44,909 - decision_learning.modeling.train - INFO - epoch: 8, train_loss: 0.024219383618661335, val_metric: -0.20084145033918466, test_regret: 0.045970491557533064
# Training Loader: Epoch 9/100: 100%|██████████| 7/7 [00:00<00:00, 1736.87it/s]
# Validation Loader: Epoch 9/100: 100%|██████████| 7/7 [00:00<00:00, 3773.31it/s]
# 2025-01-22 09:54:44,924 - decision_learning.modeling.train - INFO - epoch: 9, train_loss: 0.023867339427982057, val_metric: -0.1771744150128665, test_regret: 0.04234173829159048
# Training Loader: Epoch 10/100: 100%|██████████| 7/7 [00:00<00:00, 1686.39it/s]
# Validation Loader: Epoch 10/100: 100%|██████████| 7/7 [00:00<00:00, 3827.42it/s]
# 2025-01-22 09:54:44,941 - decision_learning.modeling.train - INFO - epoch: 10, train_loss: 0.023588542161243304, val_metric: -0.16313286469281757, test_regret: 0.03854273768726025
# Training Loader: Epoch 11/100: 100%|██████████| 7/7 [00:00<00:00, 1655.21it/s]
# Validation Loader: Epoch 11/100: 100%|██████████| 7/7 [00:00<00:00, 3813.00it/s]
# 2025-01-22 09:54:44,957 - decision_learning.modeling.train - INFO - epoch: 11, train_loss: 0.022746581318123, val_metric: -0.18146825763099164, test_regret: 0.03792898469276925
# Training Loader: Epoch 12/100: 100%|██████████| 7/7 [00:00<00:00, 1619.24it/s]
# Validation Loader: Epoch 12/100: 100%|██████████| 7/7 [00:00<00:00, 3567.89it/s]
# 2025-01-22 09:54:44,973 - decision_learning.modeling.train - INFO - epoch: 12, train_loss: 0.022520560771226883, val_metric: -0.1646819763070359, test_regret: 0.03780688973546561
# Training Loader: Epoch 13/100: 100%|██████████| 7/7 [00:00<00:00, 1730.53it/s]
# Validation Loader: Epoch 13/100: 100%|██████████| 7/7 [00:00<00:00, 3475.39it/s]
# 2025-01-22 09:54:44,991 - decision_learning.modeling.train - INFO - epoch: 13, train_loss: 0.022318591496774128, val_metric: -0.17110670359318583, test_regret: 0.0368936771457207
# Training Loader: Epoch 14/100: 100%|██████████| 7/7 [00:00<00:00, 1651.77it/s]
# Validation Loader: Epoch 14/100: 100%|██████████| 7/7 [00:00<00:00, 3421.13it/s]
# 2025-01-22 09:54:45,008 - decision_learning.modeling.train - INFO - epoch: 14, train_loss: 0.02310644249830927, val_metric: -0.18380283903898628, test_regret: 0.03650522517781517
# Training Loader: Epoch 15/100: 100%|██████████| 7/7 [00:00<00:00, 1584.46it/s]
# Validation Loader: Epoch 15/100: 100%|██████████| 7/7 [00:00<00:00, 3733.01it/s]
# 2025-01-22 09:54:45,024 - decision_learning.modeling.train - INFO - epoch: 15, train_loss: 0.022092762536236217, val_metric: -0.1574289489523147, test_regret: 0.03573682158998884
# Training Loader: Epoch 16/100: 100%|██████████| 7/7 [00:00<00:00, 1648.61it/s]
# Validation Loader: Epoch 16/100: 100%|██████████| 7/7 [00:00<00:00, 3810.03it/s]
# 2025-01-22 09:54:45,040 - decision_learning.modeling.train - INFO - epoch: 16, train_loss: 0.022331144394619123, val_metric: -0.16896579457086477, test_regret: 0.03493535722250058
# Training Loader: Epoch 17/100: 100%|██████████| 7/7 [00:00<00:00, 1646.76it/s]
# Validation Loader: Epoch 17/100: 100%|██████████| 7/7 [00:00<00:00, 3692.17it/s]
# 2025-01-22 09:54:45,056 - decision_learning.modeling.train - INFO - epoch: 17, train_loss: 0.02254918829670974, val_metric: -0.18738090554697517, test_regret: 0.034736905450799674
# Training Loader: Epoch 18/100: 100%|██████████| 7/7 [00:00<00:00, 1594.88it/s]
# Validation Loader: Epoch 18/100: 100%|██████████| 7/7 [00:00<00:00, 2979.82it/s]
# 2025-01-22 09:54:45,073 - decision_learning.modeling.train - INFO - epoch: 18, train_loss: 0.022200084158352444, val_metric: -0.1771692749147238, test_regret: 0.033916719415249964
# Training Loader: Epoch 19/100: 100%|██████████| 7/7 [00:00<00:00, 1679.83it/s]
# Validation Loader: Epoch 19/100: 100%|██████████| 7/7 [00:00<00:00, 3574.84it/s]
# 2025-01-22 09:54:45,089 - decision_learning.modeling.train - INFO - epoch: 19, train_loss: 0.021992131003311703, val_metric: -0.185947608949505, test_regret: 0.033915670806748566
# Training Loader: Epoch 20/100: 100%|██████████| 7/7 [00:00<00:00, 1738.62it/s]
# Validation Loader: Epoch 20/100: 100%|██████████| 7/7 [00:00<00:00, 3723.54it/s]
# 2025-01-22 09:54:45,105 - decision_learning.modeling.train - INFO - epoch: 20, train_loss: 0.021981788533074514, val_metric: -0.15744188060194056, test_regret: 0.03389276863967823
# Training Loader: Epoch 21/100: 100%|██████████| 7/7 [00:00<00:00, 1672.75it/s]
# Validation Loader: Epoch 21/100: 100%|██████████| 7/7 [00:00<00:00, 2862.73it/s]
# 2025-01-22 09:54:45,122 - decision_learning.modeling.train - INFO - epoch: 21, train_loss: 0.021997586424861635, val_metric: -0.1659730945337096, test_regret: 0.03393546198580646
# Training Loader: Epoch 22/100: 100%|██████████| 7/7 [00:00<00:00, 1659.05it/s]
# Validation Loader: Epoch 22/100: 100%|██████████| 7/7 [00:00<00:00, 3512.40it/s]
# 2025-01-22 09:54:45,140 - decision_learning.modeling.train - INFO - epoch: 22, train_loss: 0.02360170068485396, val_metric: -0.1677322059041723, test_regret: 0.03364728277037819
# Training Loader: Epoch 23/100: 100%|██████████| 7/7 [00:00<00:00, 1640.14it/s]
# Validation Loader: Epoch 23/100: 100%|██████████| 7/7 [00:00<00:00, 2924.02it/s]
# 2025-01-22 09:54:45,157 - decision_learning.modeling.train - INFO - epoch: 23, train_loss: 0.0216430202126503, val_metric: -0.17688673232541643, test_regret: 0.03331058886395183
# Training Loader: Epoch 24/100: 100%|██████████| 7/7 [00:00<00:00, 1624.44it/s]
# Validation Loader: Epoch 24/100: 100%|██████████| 7/7 [00:00<00:00, 3831.41it/s]
# 2025-01-22 09:54:45,174 - decision_learning.modeling.train - INFO - epoch: 24, train_loss: 0.021771216232861792, val_metric: -0.19587088240178985, test_regret: 0.03343615711918201
# Training Loader: Epoch 25/100: 100%|██████████| 7/7 [00:00<00:00, 1716.46it/s]
# Validation Loader: Epoch 25/100: 100%|██████████| 7/7 [00:00<00:00, 3344.74it/s]
# 2025-01-22 09:54:45,190 - decision_learning.modeling.train - INFO - epoch: 25, train_loss: 0.022162596828171184, val_metric: -0.18182715742483443, test_regret: 0.03326644279441801
# Training Loader: Epoch 26/100: 100%|██████████| 7/7 [00:00<00:00, 1690.86it/s]
# Validation Loader: Epoch 26/100: 100%|██████████| 7/7 [00:00<00:00, 3426.72it/s]
# 2025-01-22 09:54:45,207 - decision_learning.modeling.train - INFO - epoch: 26, train_loss: 0.024049552157521248, val_metric: -0.1674619204719743, test_regret: 0.03342719691630631
# Training Loader: Epoch 27/100: 100%|██████████| 7/7 [00:00<00:00, 1609.48it/s]
# Validation Loader: Epoch 27/100: 100%|██████████| 7/7 [00:00<00:00, 3489.44it/s]
# 2025-01-22 09:54:45,223 - decision_learning.modeling.train - INFO - epoch: 27, train_loss: 0.022263368059481894, val_metric: -0.18027118459363836, test_regret: 0.033522519261207216
# Training Loader: Epoch 28/100: 100%|██████████| 7/7 [00:00<00:00, 1609.22it/s]
# Validation Loader: Epoch 28/100: 100%|██████████| 7/7 [00:00<00:00, 3234.56it/s]
# 2025-01-22 09:54:45,240 - decision_learning.modeling.train - INFO - epoch: 28, train_loss: 0.021896409136908396, val_metric: -0.14078340398067204, test_regret: 0.0333572536841385
# Training Loader: Epoch 29/100: 100%|██████████| 7/7 [00:00<00:00, 1731.04it/s]
# Validation Loader: Epoch 29/100: 100%|██████████| 7/7 [00:00<00:00, 3709.90it/s]
# 2025-01-22 09:54:45,256 - decision_learning.modeling.train - INFO - epoch: 29, train_loss: 0.022363227659038136, val_metric: -0.17333170322561892, test_regret: 0.033345931499322766
# Training Loader: Epoch 30/100: 100%|██████████| 7/7 [00:00<00:00, 1727.57it/s]
# Validation Loader: Epoch 30/100: 100%|██████████| 7/7 [00:00<00:00, 1611.42it/s]
# 2025-01-22 09:54:45,298 - decision_learning.modeling.train - INFO - epoch: 30, train_loss: 0.022070468004260744, val_metric: -0.15664877043603817, test_regret: 0.03334433942595022
# Training Loader: Epoch 31/100: 100%|██████████| 7/7 [00:00<00:00, 759.70it/s]
# Validation Loader: Epoch 31/100: 100%|██████████| 7/7 [00:00<00:00, 2948.69it/s]
# 2025-01-22 09:54:45,339 - decision_learning.modeling.train - INFO - epoch: 31, train_loss: 0.022162983992270062, val_metric: -0.15286313467070042, test_regret: 0.03326443267114457
# Training Loader: Epoch 32/100: 100%|██████████| 7/7 [00:00<00:00, 1241.18it/s]
# Validation Loader: Epoch 32/100: 100%|██████████| 7/7 [00:00<00:00, 3429.92it/s]
# 2025-01-22 09:54:45,360 - decision_learning.modeling.train - INFO - epoch: 32, train_loss: 0.022911510031138147, val_metric: -0.18115522332826786, test_regret: 0.03310678953726871
# Training Loader: Epoch 33/100: 100%|██████████| 7/7 [00:00<00:00, 1253.15it/s]
# Validation Loader: Epoch 33/100: 100%|██████████| 7/7 [00:00<00:00, 3512.40it/s]
# 2025-01-22 09:54:45,377 - decision_learning.modeling.train - INFO - epoch: 33, train_loss: 0.022043108407940184, val_metric: -0.16848934701225743, test_regret: 0.033018354564484945
# Training Loader: Epoch 34/100: 100%|██████████| 7/7 [00:00<00:00, 1554.84it/s]
# Validation Loader: Epoch 34/100: 100%|██████████| 7/7 [00:00<00:00, 2799.94it/s]
# 2025-01-22 09:54:45,394 - decision_learning.modeling.train - INFO - epoch: 34, train_loss: 0.021791723423770497, val_metric: -0.16761723981766039, test_regret: 0.033169611986124725
# Training Loader: Epoch 35/100: 100%|██████████| 7/7 [00:00<00:00, 1553.53it/s]
# Validation Loader: Epoch 35/100: 100%|██████████| 7/7 [00:00<00:00, 2360.90it/s]
# 2025-01-22 09:54:45,412 - decision_learning.modeling.train - INFO - epoch: 35, train_loss: 0.023010360343115672, val_metric: -0.1703823800347807, test_regret: 0.033132422963691524
# Training Loader: Epoch 36/100: 100%|██████████| 7/7 [00:00<00:00, 1396.64it/s]
# Validation Loader: Epoch 36/100: 100%|██████████| 7/7 [00:00<00:00, 2629.89it/s]
# 2025-01-22 09:54:45,431 - decision_learning.modeling.train - INFO - epoch: 36, train_loss: 0.0219964435590165, val_metric: -0.19325506087279545, test_regret: 0.03320069399625578
# Training Loader: Epoch 37/100: 100%|██████████| 7/7 [00:00<00:00, 1525.12it/s]
# Validation Loader: Epoch 37/100: 100%|██████████| 7/7 [00:00<00:00, 3506.94it/s]
# 2025-01-22 09:54:45,448 - decision_learning.modeling.train - INFO - epoch: 37, train_loss: 0.02198894029217107, val_metric: -0.15669834563599774, test_regret: 0.03325491506840101
# Training Loader: Epoch 38/100: 100%|██████████| 7/7 [00:00<00:00, 1740.89it/s]
# Validation Loader: Epoch 38/100: 100%|██████████| 7/7 [00:00<00:00, 3274.24it/s]
# 2025-01-22 09:54:45,465 - decision_learning.modeling.train - INFO - epoch: 38, train_loss: 0.022492327860423496, val_metric: -0.16904407059031767, test_regret: 0.033311992814868976
# Training Loader: Epoch 39/100: 100%|██████████| 7/7 [00:00<00:00, 1576.89it/s]
# Validation Loader: Epoch 39/100: 100%|██████████| 7/7 [00:00<00:00, 4226.91it/s]
# 2025-01-22 09:54:45,481 - decision_learning.modeling.train - INFO - epoch: 39, train_loss: 0.022537622334701673, val_metric: -0.18348864181813068, test_regret: 0.03367448388392934
# Training Loader: Epoch 40/100: 100%|██████████| 7/7 [00:00<00:00, 1753.16it/s]
# Validation Loader: Epoch 40/100: 100%|██████████| 7/7 [00:00<00:00, 2953.44it/s]
# 2025-01-22 09:54:45,498 - decision_learning.modeling.train - INFO - epoch: 40, train_loss: 0.022622913654361452, val_metric: -0.16743733638266758, test_regret: 0.033451882762953765
# Training Loader: Epoch 41/100: 100%|██████████| 7/7 [00:00<00:00, 1640.05it/s]
# Validation Loader: Epoch 41/100: 100%|██████████| 7/7 [00:00<00:00, 3290.76it/s]
# 2025-01-22 09:54:45,515 - decision_learning.modeling.train - INFO - epoch: 41, train_loss: 0.022665402718952725, val_metric: -0.18491565865768905, test_regret: 0.03350896050942173
# Training Loader: Epoch 42/100: 100%|██████████| 7/7 [00:00<00:00, 1704.80it/s]
# Validation Loader: Epoch 42/100: 100%|██████████| 7/7 [00:00<00:00, 3021.21it/s]
# 2025-01-22 09:54:45,531 - decision_learning.modeling.train - INFO - epoch: 42, train_loss: 0.02305084839463234, val_metric: -0.17671018972382457, test_regret: 0.03339195182591224
# Training Loader: Epoch 43/100: 100%|██████████| 7/7 [00:00<00:00, 1572.58it/s]
# Validation Loader: Epoch 43/100: 100%|██████████| 7/7 [00:00<00:00, 2763.31it/s]
# 2025-01-22 09:54:45,548 - decision_learning.modeling.train - INFO - epoch: 43, train_loss: 0.022040491657597677, val_metric: -0.18999235450379393, test_regret: 0.03339195182591224
# Training Loader: Epoch 44/100: 100%|██████████| 7/7 [00:00<00:00, 1615.24it/s]
# Validation Loader: Epoch 44/100: 100%|██████████| 7/7 [00:00<00:00, 3582.69it/s]
# 2025-01-22 09:54:45,564 - decision_learning.modeling.train - INFO - epoch: 44, train_loss: 0.02166511757033212, val_metric: -0.18282368523035505, test_regret: 0.03339195182591224
# Training Loader: Epoch 45/100: 100%|██████████| 7/7 [00:00<00:00, 1517.87it/s]
# Validation Loader: Epoch 45/100: 100%|██████████| 7/7 [00:00<00:00, 2871.13it/s]
# 2025-01-22 09:54:45,583 - decision_learning.modeling.train - INFO - epoch: 45, train_loss: 0.02282701539141791, val_metric: -0.1855579499710755, test_regret: 0.033594577129123684
# Training Loader: Epoch 46/100: 100%|██████████| 7/7 [00:00<00:00, 1251.12it/s]
# Validation Loader: Epoch 46/100: 100%|██████████| 7/7 [00:00<00:00, 3932.51it/s]
# 2025-01-22 09:54:45,602 - decision_learning.modeling.train - INFO - epoch: 46, train_loss: 0.021790129797799245, val_metric: -0.1940108064791224, test_regret: 0.03353464619208216
# Training Loader: Epoch 47/100: 100%|██████████| 7/7 [00:00<00:00, 1313.59it/s]
# Validation Loader: Epoch 47/100: 100%|██████████| 7/7 [00:00<00:00, 3126.41it/s]
# 2025-01-22 09:54:45,619 - decision_learning.modeling.train - INFO - epoch: 47, train_loss: 0.021904421970248222, val_metric: -0.17455803528316882, test_regret: 0.033594577129123684
# Training Loader: Epoch 48/100: 100%|██████████| 7/7 [00:00<00:00, 1311.13it/s]
# Validation Loader: Epoch 48/100: 100%|██████████| 7/7 [00:00<00:00, 3297.41it/s]
# 2025-01-22 09:54:45,638 - decision_learning.modeling.train - INFO - epoch: 48, train_loss: 0.02329087443649769, val_metric: -0.19165618799171646, test_regret: 0.033594577129123684
# Training Loader: Epoch 49/100: 100%|██████████| 7/7 [00:00<00:00, 1554.10it/s]
# Validation Loader: Epoch 49/100: 100%|██████████| 7/7 [00:00<00:00, 2663.53it/s]
# 2025-01-22 09:54:45,658 - decision_learning.modeling.train - INFO - epoch: 49, train_loss: 0.022020692537937845, val_metric: -0.18630788098674333, test_regret: 0.033594577129123684
# Training Loader: Epoch 50/100: 100%|██████████| 7/7 [00:00<00:00, 1368.58it/s]
# Validation Loader: Epoch 50/100: 100%|██████████| 7/7 [00:00<00:00, 3670.47it/s]
# 2025-01-22 09:54:45,676 - decision_learning.modeling.train - INFO - epoch: 50, train_loss: 0.02267428088401045, val_metric: -0.18319636560405994, test_regret: 0.033417634024823485
# Training Loader: Epoch 51/100: 100%|██████████| 7/7 [00:00<00:00, 1561.04it/s]
# Validation Loader: Epoch 51/100: 100%|██████████| 7/7 [00:00<00:00, 2475.98it/s]
# 2025-01-22 09:54:45,694 - decision_learning.modeling.train - INFO - epoch: 51, train_loss: 0.02255591670317309, val_metric: -0.18719817622092205, test_regret: 0.033417634024823485
# Training Loader: Epoch 52/100: 100%|██████████| 7/7 [00:00<00:00, 1568.47it/s]
# Validation Loader: Epoch 52/100: 100%|██████████| 7/7 [00:00<00:00, 2671.53it/s]
# 2025-01-22 09:54:45,713 - decision_learning.modeling.train - INFO - epoch: 52, train_loss: 0.022232196959001676, val_metric: -0.18587135640760144, test_regret: 0.033417634024823485
# Training Loader: Epoch 53/100: 100%|██████████| 7/7 [00:00<00:00, 1609.66it/s]
# Validation Loader: Epoch 53/100: 100%|██████████| 7/7 [00:00<00:00, 3377.06it/s]
# 2025-01-22 09:54:45,730 - decision_learning.modeling.train - INFO - epoch: 53, train_loss: 0.02256279837872301, val_metric: -0.18020574719036075, test_regret: 0.033417634024823485
# Training Loader: Epoch 54/100: 100%|██████████| 7/7 [00:00<00:00, 1611.78it/s]
# Validation Loader: Epoch 54/100: 100%|██████████| 7/7 [00:00<00:00, 3263.69it/s]
# 2025-01-22 09:54:45,746 - decision_learning.modeling.train - INFO - epoch: 54, train_loss: 0.022470126194613322, val_metric: -0.17668252390146855, test_regret: 0.033417634024823485
# Training Loader: Epoch 55/100: 100%|██████████| 7/7 [00:00<00:00, 1651.39it/s]
# Validation Loader: Epoch 55/100: 100%|██████████| 7/7 [00:00<00:00, 3597.17it/s]
# 2025-01-22 09:54:45,763 - decision_learning.modeling.train - INFO - epoch: 55, train_loss: 0.02269321068056992, val_metric: -0.18098985636992282, test_regret: 0.033417634024823485
# Training Loader: Epoch 56/100: 100%|██████████| 7/7 [00:00<00:00, 1561.79it/s]
# Validation Loader: Epoch 56/100: 100%|██████████| 7/7 [00:00<00:00, 3338.27it/s]
# 2025-01-22 09:54:45,780 - decision_learning.modeling.train - INFO - epoch: 56, train_loss: 0.022155465558171272, val_metric: -0.1821561004476015, test_regret: 0.033417634024823485
# Training Loader: Epoch 57/100: 100%|██████████| 7/7 [00:00<00:00, 1644.92it/s]
# Validation Loader: Epoch 57/100: 100%|██████████| 7/7 [00:00<00:00, 3674.61it/s]
# 2025-01-22 09:54:45,795 - decision_learning.modeling.train - INFO - epoch: 57, train_loss: 0.02243991754949093, val_metric: -0.19198340989564844, test_regret: 0.033417634024823485
# Training Loader: Epoch 58/100: 100%|██████████| 7/7 [00:00<00:00, 1725.85it/s]
# Validation Loader: Epoch 58/100: 100%|██████████| 7/7 [00:00<00:00, 2263.17it/s]
# 2025-01-22 09:54:45,812 - decision_learning.modeling.train - INFO - epoch: 58, train_loss: 0.021421956696680615, val_metric: -0.191257283814139, test_regret: 0.033417634024823485
# Training Loader: Epoch 59/100: 100%|██████████| 7/7 [00:00<00:00, 1665.92it/s]
# Validation Loader: Epoch 59/100: 100%|██████████| 7/7 [00:00<00:00, 2188.77it/s]
# 2025-01-22 09:54:45,829 - decision_learning.modeling.train - INFO - epoch: 59, train_loss: 0.022171287398253168, val_metric: -0.17706607755970596, test_regret: 0.033417634024823485
# Training Loader: Epoch 60/100: 100%|██████████| 7/7 [00:00<00:00, 1762.42it/s]
# Validation Loader: Epoch 60/100: 100%|██████████| 7/7 [00:00<00:00, 3068.90it/s]
# 2025-01-22 09:54:45,845 - decision_learning.modeling.train - INFO - epoch: 60, train_loss: 0.02242152765393257, val_metric: -0.17690444356856408, test_regret: 0.033417634024823485
# Training Loader: Epoch 61/100: 100%|██████████| 7/7 [00:00<00:00, 1473.31it/s]
# Validation Loader: Epoch 61/100: 100%|██████████| 7/7 [00:00<00:00, 2763.57it/s]
# 2025-01-22 09:54:45,861 - decision_learning.modeling.train - INFO - epoch: 61, train_loss: 0.02212322609765189, val_metric: -0.18756026241044604, test_regret: 0.033417634024823485
# Training Loader: Epoch 62/100: 100%|██████████| 7/7 [00:00<00:00, 1409.38it/s]
# Validation Loader: Epoch 62/100: 100%|██████████| 7/7 [00:00<00:00, 2680.07it/s]
# 2025-01-22 09:54:45,882 - decision_learning.modeling.train - INFO - epoch: 62, train_loss: 0.022334637652550424, val_metric: -0.19811710529012866, test_regret: 0.033417634024823485
# Training Loader: Epoch 63/100: 100%|██████████| 7/7 [00:00<00:00, 1304.72it/s]
# Validation Loader: Epoch 63/100: 100%|██████████| 7/7 [00:00<00:00, 3939.37it/s]
# 2025-01-22 09:54:45,899 - decision_learning.modeling.train - INFO - epoch: 63, train_loss: 0.022163892164826393, val_metric: -0.16879479908876172, test_regret: 0.033417634024823485
# Training Loader: Epoch 64/100: 100%|██████████| 7/7 [00:00<00:00, 1574.10it/s]
# Validation Loader: Epoch 64/100: 100%|██████████| 7/7 [00:00<00:00, 3549.77it/s]
# 2025-01-22 09:54:45,915 - decision_learning.modeling.train - INFO - epoch: 64, train_loss: 0.021867615303822925, val_metric: -0.1762096348723446, test_regret: 0.033417634024823485
# Training Loader: Epoch 65/100: 100%|██████████| 7/7 [00:00<00:00, 1576.55it/s]
# Validation Loader: Epoch 65/100: 100%|██████████| 7/7 [00:00<00:00, 3407.63it/s]
# 2025-01-22 09:54:45,930 - decision_learning.modeling.train - INFO - epoch: 65, train_loss: 0.023151073338729993, val_metric: -0.13874308737675356, test_regret: 0.033417634024823485
# Training Loader: Epoch 66/100: 100%|██████████| 7/7 [00:00<00:00, 1740.89it/s]
# Validation Loader: Epoch 66/100: 100%|██████████| 7/7 [00:00<00:00, 2519.10it/s]
# 2025-01-22 09:54:45,947 - decision_learning.modeling.train - INFO - epoch: 66, train_loss: 0.021941270945327624, val_metric: -0.1649402604241135, test_regret: 0.033417634024823485
# Training Loader: Epoch 67/100: 100%|██████████| 7/7 [00:00<00:00, 1665.44it/s]
# Validation Loader: Epoch 67/100: 100%|██████████| 7/7 [00:00<00:00, 2903.21it/s]
# 2025-01-22 09:54:45,965 - decision_learning.modeling.train - INFO - epoch: 67, train_loss: 0.021961105189153125, val_metric: -0.15707823610211993, test_regret: 0.033417634024823485
# Training Loader: Epoch 68/100: 100%|██████████| 7/7 [00:00<00:00, 1485.54it/s]
# Validation Loader: Epoch 68/100: 100%|██████████| 7/7 [00:00<00:00, 3842.45it/s]
# 2025-01-22 09:54:45,981 - decision_learning.modeling.train - INFO - epoch: 68, train_loss: 0.021919299183147296, val_metric: -0.18323045073450364, test_regret: 0.033417634024823485
# Training Loader: Epoch 69/100: 100%|██████████| 7/7 [00:00<00:00, 1654.93it/s]
# Validation Loader: Epoch 69/100: 100%|██████████| 7/7 [00:00<00:00, 3339.41it/s]
# 2025-01-22 09:54:45,998 - decision_learning.modeling.train - INFO - epoch: 69, train_loss: 0.023025485553911755, val_metric: -0.17492647100569256, test_regret: 0.033417634024823485
# Training Loader: Epoch 70/100: 100%|██████████| 7/7 [00:00<00:00, 1564.21it/s]
# Validation Loader: Epoch 70/100: 100%|██████████| 7/7 [00:00<00:00, 3653.57it/s]
# 2025-01-22 09:54:46,028 - decision_learning.modeling.train - INFO - epoch: 70, train_loss: 0.021633673725383624, val_metric: -0.19003131226120995, test_regret: 0.033417634024823485
# Training Loader: Epoch 71/100: 100%|██████████| 7/7 [00:00<00:00, 1166.47it/s]
# Validation Loader: Epoch 71/100: 100%|██████████| 7/7 [00:00<00:00, 2475.14it/s]
# 2025-01-22 09:54:46,062 - decision_learning.modeling.train - INFO - epoch: 71, train_loss: 0.021651325481278554, val_metric: -0.15586091666009164, test_regret: 0.033417634024823485
# Training Loader: Epoch 72/100: 100%|██████████| 7/7 [00:00<00:00, 1473.01it/s]
# Validation Loader: Epoch 72/100: 100%|██████████| 7/7 [00:00<00:00, 2031.42it/s]
# 2025-01-22 09:54:46,084 - decision_learning.modeling.train - INFO - epoch: 72, train_loss: 0.02305802862559046, val_metric: -0.17845370636213953, test_regret: 0.033417634024823485
# Training Loader: Epoch 73/100: 100%|██████████| 7/7 [00:00<00:00, 1234.60it/s]
# Validation Loader: Epoch 73/100: 100%|██████████| 7/7 [00:00<00:00, 1510.84it/s]
# 2025-01-22 09:54:46,111 - decision_learning.modeling.train - INFO - epoch: 73, train_loss: 0.021916753479412625, val_metric: -0.16517619325469748, test_regret: 0.033417634024823485
# Training Loader: Epoch 74/100: 100%|██████████| 7/7 [00:00<00:00, 1394.38it/s]
# Validation Loader: Epoch 74/100: 100%|██████████| 7/7 [00:00<00:00, 3484.88it/s]
# 2025-01-22 09:54:46,130 - decision_learning.modeling.train - INFO - epoch: 74, train_loss: 0.021770380969558443, val_metric: -0.17949484370719684, test_regret: 0.033417634024823485
# Training Loader: Epoch 75/100: 100%|██████████| 7/7 [00:00<00:00, 1463.25it/s]
# Validation Loader: Epoch 75/100: 100%|██████████| 7/7 [00:00<00:00, 2930.15it/s]
# 2025-01-22 09:54:46,148 - decision_learning.modeling.train - INFO - epoch: 75, train_loss: 0.022720117388027056, val_metric: -0.1636601666613295, test_regret: 0.033417634024823485
# Training Loader: Epoch 76/100: 100%|██████████| 7/7 [00:00<00:00, 1534.69it/s]
# Validation Loader: Epoch 76/100: 100%|██████████| 7/7 [00:00<00:00, 3362.36it/s]
# 2025-01-22 09:54:46,165 - decision_learning.modeling.train - INFO - epoch: 76, train_loss: 0.021673822243298804, val_metric: -0.18590234817581447, test_regret: 0.033417634024823485
# Training Loader: Epoch 77/100: 100%|██████████| 7/7 [00:00<00:00, 1574.19it/s]
# Validation Loader: Epoch 77/100: 100%|██████████| 7/7 [00:00<00:00, 2892.34it/s]
# 2025-01-22 09:54:46,182 - decision_learning.modeling.train - INFO - epoch: 77, train_loss: 0.022418252059391568, val_metric: -0.15703974351195663, test_regret: 0.033417634024823485
# Training Loader: Epoch 78/100: 100%|██████████| 7/7 [00:00<00:00, 1408.70it/s]
# Validation Loader: Epoch 78/100: 100%|██████████| 7/7 [00:00<00:00, 3357.36it/s]
# 2025-01-22 09:54:46,199 - decision_learning.modeling.train - INFO - epoch: 78, train_loss: 0.02232251236481326, val_metric: -0.18576005351320476, test_regret: 0.033417634024823485
# Training Loader: Epoch 79/100: 100%|██████████| 7/7 [00:00<00:00, 1514.19it/s]
# Validation Loader: Epoch 79/100: 100%|██████████| 7/7 [00:00<00:00, 3528.01it/s]
# 2025-01-22 09:54:46,215 - decision_learning.modeling.train - INFO - epoch: 79, train_loss: 0.021880449194993292, val_metric: -0.21006583325260733, test_regret: 0.033417634024823485
# Training Loader: Epoch 80/100: 100%|██████████| 7/7 [00:00<00:00, 1395.78it/s]
# Validation Loader: Epoch 80/100: 100%|██████████| 7/7 [00:00<00:00, 3828.92it/s]
# 2025-01-22 09:54:46,231 - decision_learning.modeling.train - INFO - epoch: 80, train_loss: 0.02162702035691057, val_metric: -0.15838565844100175, test_regret: 0.033417634024823485
# Training Loader: Epoch 81/100: 100%|██████████| 7/7 [00:00<00:00, 1757.88it/s]
# Validation Loader: Epoch 81/100: 100%|██████████| 7/7 [00:00<00:00, 3056.44it/s]
# 2025-01-22 09:54:46,248 - decision_learning.modeling.train - INFO - epoch: 81, train_loss: 0.022114067737545286, val_metric: -0.17381593070652812, test_regret: 0.033417634024823485
# Training Loader: Epoch 82/100: 100%|██████████| 7/7 [00:00<00:00, 1716.97it/s]
# Validation Loader: Epoch 82/100: 100%|██████████| 7/7 [00:00<00:00, 3484.05it/s]
# 2025-01-22 09:54:46,265 - decision_learning.modeling.train - INFO - epoch: 82, train_loss: 0.02183301667017596, val_metric: -0.19753266915380036, test_regret: 0.033417634024823485
# Training Loader: Epoch 83/100: 100%|██████████| 7/7 [00:00<00:00, 1598.18it/s]
# Validation Loader: Epoch 83/100: 100%|██████████| 7/7 [00:00<00:00, 3233.14it/s]
# 2025-01-22 09:54:46,284 - decision_learning.modeling.train - INFO - epoch: 83, train_loss: 0.022160905812467848, val_metric: -0.16996153159205574, test_regret: 0.033417634024823485
# Training Loader: Epoch 84/100: 100%|██████████| 7/7 [00:00<00:00, 1308.15it/s]
# Validation Loader: Epoch 84/100: 100%|██████████| 7/7 [00:00<00:00, 3930.41it/s]
# 2025-01-22 09:54:46,302 - decision_learning.modeling.train - INFO - epoch: 84, train_loss: 0.0221828536263534, val_metric: -0.1862157429831591, test_regret: 0.033417634024823485
# Training Loader: Epoch 85/100: 100%|██████████| 7/7 [00:00<00:00, 1348.53it/s]
# Validation Loader: Epoch 85/100: 100%|██████████| 7/7 [00:00<00:00, 3551.91it/s]
# 2025-01-22 09:54:46,320 - decision_learning.modeling.train - INFO - epoch: 85, train_loss: 0.02256369377885546, val_metric: -0.16945026626458168, test_regret: 0.033417634024823485
# Training Loader: Epoch 86/100: 100%|██████████| 7/7 [00:00<00:00, 1440.99it/s]
# Validation Loader: Epoch 86/100: 100%|██████████| 7/7 [00:00<00:00, 2786.65it/s]
# 2025-01-22 09:54:46,338 - decision_learning.modeling.train - INFO - epoch: 86, train_loss: 0.022151119208761623, val_metric: -0.16158325302380258, test_regret: 0.033417634024823485
# Training Loader: Epoch 87/100: 100%|██████████| 7/7 [00:00<00:00, 1504.03it/s]
# Validation Loader: Epoch 87/100: 100%|██████████| 7/7 [00:00<00:00, 3333.35it/s]
# 2025-01-22 09:54:46,356 - decision_learning.modeling.train - INFO - epoch: 87, train_loss: 0.022137736635548726, val_metric: -0.20382803342696643, test_regret: 0.033417634024823485
# Training Loader: Epoch 88/100: 100%|██████████| 7/7 [00:00<00:00, 1662.24it/s]
# Validation Loader: Epoch 88/100: 100%|██████████| 7/7 [00:00<00:00, 2714.26it/s]
# 2025-01-22 09:54:46,375 - decision_learning.modeling.train - INFO - epoch: 88, train_loss: 0.02207085516835962, val_metric: -0.1620183821011863, test_regret: 0.033417634024823485
# Training Loader: Epoch 89/100: 100%|██████████| 7/7 [00:00<00:00, 1407.08it/s]
# Validation Loader: Epoch 89/100: 100%|██████████| 7/7 [00:00<00:00, 3399.74it/s]
# 2025-01-22 09:54:46,393 - decision_learning.modeling.train - INFO - epoch: 89, train_loss: 0.022198883816599846, val_metric: -0.16068095647450345, test_regret: 0.033417634024823485
# Training Loader: Epoch 90/100: 100%|██████████| 7/7 [00:00<00:00, 1440.63it/s]
# Validation Loader: Epoch 90/100: 100%|██████████| 7/7 [00:00<00:00, 3393.45it/s]
# 2025-01-22 09:54:46,411 - decision_learning.modeling.train - INFO - epoch: 90, train_loss: 0.021986535351191248, val_metric: -0.1794611655980993, test_regret: 0.033417634024823485
# Training Loader: Epoch 91/100: 100%|██████████| 7/7 [00:00<00:00, 1662.71it/s]
# Validation Loader: Epoch 91/100: 100%|██████████| 7/7 [00:00<00:00, 3439.97it/s]
# 2025-01-22 09:54:46,427 - decision_learning.modeling.train - INFO - epoch: 91, train_loss: 0.022000660853726522, val_metric: -0.1495097788333234, test_regret: 0.033417634024823485
# Training Loader: Epoch 92/100: 100%|██████████| 7/7 [00:00<00:00, 1560.88it/s]
# Validation Loader: Epoch 92/100: 100%|██████████| 7/7 [00:00<00:00, 2746.25it/s]
# 2025-01-22 09:54:46,445 - decision_learning.modeling.train - INFO - epoch: 92, train_loss: 0.021942191092031344, val_metric: -0.1442511095579511, test_regret: 0.033417634024823485
# Training Loader: Epoch 93/100: 100%|██████████| 7/7 [00:00<00:00, 1429.13it/s]
# Validation Loader: Epoch 93/100: 100%|██████████| 7/7 [00:00<00:00, 2913.29it/s]
# 2025-01-22 09:54:46,462 - decision_learning.modeling.train - INFO - epoch: 93, train_loss: 0.02218726836144924, val_metric: -0.1744323936082068, test_regret: 0.033417634024823485
# Training Loader: Epoch 94/100: 100%|██████████| 7/7 [00:00<00:00, 1559.06it/s]
# Validation Loader: Epoch 94/100: 100%|██████████| 7/7 [00:00<00:00, 2268.94it/s]
# 2025-01-22 09:54:46,478 - decision_learning.modeling.train - INFO - epoch: 94, train_loss: 0.021888616095696176, val_metric: -0.1789091516192862, test_regret: 0.033417634024823485
# Training Loader: Epoch 95/100: 100%|██████████| 7/7 [00:00<00:00, 1563.54it/s]
# Validation Loader: Epoch 95/100: 100%|██████████| 7/7 [00:00<00:00, 2890.35it/s]
# 2025-01-22 09:54:46,494 - decision_learning.modeling.train - INFO - epoch: 95, train_loss: 0.022716368149433817, val_metric: -0.15455378505074277, test_regret: 0.033417634024823485
# Training Loader: Epoch 96/100: 100%|██████████| 7/7 [00:00<00:00, 1633.66it/s]
# Validation Loader: Epoch 96/100: 100%|██████████| 7/7 [00:00<00:00, 3456.98it/s]
# 2025-01-22 09:54:46,509 - decision_learning.modeling.train - INFO - epoch: 96, train_loss: 0.022626208141446114, val_metric: -0.19731413357846844, test_regret: 0.033417634024823485
# Training Loader: Epoch 97/100: 100%|██████████| 7/7 [00:00<00:00, 1358.38it/s]
# Validation Loader: Epoch 97/100: 100%|██████████| 7/7 [00:00<00:00, 3943.60it/s]
# 2025-01-22 09:54:46,526 - decision_learning.modeling.train - INFO - epoch: 97, train_loss: 0.022197621209280833, val_metric: -0.1658104953205183, test_regret: 0.033417634024823485
# Training Loader: Epoch 98/100: 100%|██████████| 7/7 [00:00<00:00, 1531.73it/s]
# Validation Loader: Epoch 98/100: 100%|██████████| 7/7 [00:00<00:00, 3751.13it/s]
# 2025-01-22 09:54:46,543 - decision_learning.modeling.train - INFO - epoch: 98, train_loss: 0.02167000701384885, val_metric: -0.17614539527474277, test_regret: 0.033417634024823485
# Training Loader: Epoch 99/100: 100%|██████████| 7/7 [00:00<00:00, 1602.98it/s]
# Validation Loader: Epoch 99/100: 100%|██████████| 7/7 [00:00<00:00, 3563.99it/s]
# 2025-01-22 09:54:46,559 - decision_learning.modeling.train - INFO - epoch: 99, train_loss: 0.02190901418881757, val_metric: -0.20033023152843585, test_regret: 0.033417634024823485
# Training Loader: Epoch 100/100: 100%|██████████| 7/7 [00:00<00:00, 1514.42it/s]
# Validation Loader: Epoch 100/100: 100%|██████████| 7/7 [00:00<00:00, 1529.01it/s]
# 2025-01-22 09:54:46,610 - decision_learning.modeling.train - INFO - epoch: 100, train_loss: 0.02241262554058007, val_metric: -0.188139314235824, test_regret: 0.033417634024823485
# 2025-01-22 09:54:46,617 - decision_learning.utils - INFO - Function 'train' took 1.8523027896881104 seconds to run.

# %%
metrics
# Out:
#     epoch  train_loss  val_metric  test_regret
# 0       0    0.514782   -0.343436     0.195390
# 1       1    0.054183   -0.229814     0.145180
# 2       2    0.040245   -0.195222     0.117743
# 3       3    0.034378   -0.186500     0.092686
# 4       4    0.029705   -0.218009     0.076176
# ..    ...         ...         ...          ...
# 95     95    0.022626   -0.197314     0.033418
# 96     96    0.022198   -0.165810     0.033418
# 97     97    0.021670   -0.176145     0.033418
# 98     98    0.021909   -0.200330     0.033418
# 99     99    0.022413   -0.188139     0.033418
#
# [100 rows x 4 columns]

# %%
true_cost = train_dataset.data['true_cost']
pred = trained_model(train_dataset.data['X'])

# %%
cos = nn.CosineSimilarity(dim=1, eps=1e-6)
output = cos(pred, true_cost)

# %%
output.mean()
# Out:
# tensor(0.9778, grad_fn=<MeanBackward0>)
